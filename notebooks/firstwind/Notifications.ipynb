# %%
from subprocess import check_output
import re
from pandas import DataFrame
import numpy as np
from pathlib import Path

def parse_qstat_line(line):
    job_identifier, *rest = line.split()
    split_job_identifier = list(re.match(r'([0-9]+)\[([^\]]*)\]\.(.*)', job_identifier).groups())
    return split_job_identifier + rest

def qstat():
    cmd_output = check_output(['qstat', '-t'])
    if not cmd_output: return DataFrame([], columns = ['JobId','ArrayId', 'Machine', 'JobName', 'User', 'Time', 'Status', 'Queue'])
    header, line, *body = cmd_output.decode('utf8').split('\n')
    body = [parse_qstat_line(line) for line in body if line]
    return DataFrame(body, columns = ['JobId','ArrayId', 'Machine', 'JobName', 'User', 'Time', 'Status', 'Queue'])
    
def job_summary(jobs): return jobs[jobs.ArrayId != ''].groupby(['JobName', 'Status']).agg({'ArrayId':'count'})

job_summary(qstat())
# Out:
#                         ArrayId
# JobName         Status
# phase_diagram_5 R             1

# %%
qstat()
# Out:
#       JobId ArrayId Machine          JobName   User Time Status  \
# 0   2303199             cx1  phase_diagram_5  tch14    0      Q
# 1   2303199     727     cx1  phase_diagram_5  tch14    0      Q
# 2   2303200             cx1  phase_diagram_5  tch14    0      Q
# 3   2303200     728     cx1  phase_diagram_5  tch14    0      Q
# 4   2303203             cx1  phase_diagram_5  tch14    0      Q
# 5   2303203     729     cx1  phase_diagram_5  tch14    0      Q
# 6   2303204             cx1  phase_diagram_5  tch14    0      Q
# 7   2303204     951     cx1  phase_diagram_5  tch14    0      Q
# 8   2303205             cx1  phase_diagram_5  tch14    0      Q
# 9   2303205     952     cx1  phase_diagram_5  tch14    0      Q
# 10  2303206             cx1  phase_diagram_5  tch14    0      Q
# 11  2303206     953     cx1  phase_diagram_5  tch14    0      Q
# 12  2303207             cx1  phase_diagram_5  tch14    0      Q
# 13  2303207     954     cx1  phase_diagram_5  tch14    0      Q
# 14  2303208             cx1  phase_diagram_5  tch14    0      Q
# 15  2303208    1056     cx1  phase_diagram_5  tch14    0      Q
# 16  2303209             cx1  phase_diagram_5  tch14    0      Q
# 17  2303209    1057     cx1  phase_diagram_5  tch14    0      Q
# 18  2303210             cx1  phase_diagram_5  tch14    0      Q
# 19  2303210    1058     cx1  phase_diagram_5  tch14    0      Q
# 20  2303211             cx1  phase_diagram_5  tch14    0      Q
# 21  2303211    1059     cx1  phase_diagram_5  tch14    0      Q
# 22  2303212             cx1  phase_diagram_5  tch14    0      Q
# 23  2303212    1060     cx1  phase_diagram_5  tch14    0      Q
# 24  2303213             cx1  phase_diagram_5  tch14    0      Q
# 25  2303213    1463     cx1  phase_diagram_5  tch14    0      Q
# 26  2303214             cx1  phase_diagram_5  tch14    0      Q
# 27  2303214    1464     cx1  phase_diagram_5  tch14    0      Q
# 28  2303215             cx1  phase_diagram_5  tch14    0      Q
# 29  2303215    1837     cx1  phase_diagram_5  tch14    0      Q
# 30  2303216             cx1  phase_diagram_5  tch14    0      Q
# 31  2303216    1838     cx1  phase_diagram_5  tch14    0      Q
# 32  2303217             cx1  phase_diagram_5  tch14    0      Q
# 33  2303217    1839     cx1  phase_diagram_5  tch14    0      Q
# 34  2303218             cx1  phase_diagram_5  tch14    0      Q
# 35  2303218    1840     cx1  phase_diagram_5  tch14    0      Q
# 36  2303219             cx1  phase_diagram_5  tch14    0      Q
# 37  2303219    1904     cx1  phase_diagram_5  tch14    0      Q
# 38  2303220             cx1  phase_diagram_5  tch14    0      Q
# 39  2303220    1965     cx1  phase_diagram_5  tch14    0      Q
# 40  2303221             cx1  phase_diagram_5  tch14    0      Q
# 41  2303221    1966     cx1  phase_diagram_5  tch14    0      Q
# 42  2303222             cx1  phase_diagram_5  tch14    0      Q
# 43  2303222    1967     cx1  phase_diagram_5  tch14    0      Q
# 44  2303223             cx1  phase_diagram_5  tch14    0      Q
# 45  2303223    5123     cx1  phase_diagram_5  tch14    0      Q
# 46  2303224             cx1  phase_diagram_5  tch14    0      Q
# 47  2303224    5266     cx1  phase_diagram_5  tch14    0      Q
# 48  2303225             cx1  phase_diagram_5  tch14    0      Q
# 49  2303225    5267     cx1  phase_diagram_5  tch14    0      Q
#
#               Queue
# 0   v1_throughput2a
# 1   v1_throughput2a
# 2   v1_throughput2a
# 3   v1_throughput2a
# 4   v1_throughput2a
# 5   v1_throughput2a
# 6   v1_throughput2a
# 7   v1_throughput2a
# 8   v1_throughput2a
# 9   v1_throughput2a
# 10  v1_throughput2a
# 11  v1_throughput2a
# 12  v1_throughput2a
# 13  v1_throughput2a
# 14  v1_throughput2a
# 15  v1_throughput2a
# 16  v1_throughput2a
# 17  v1_throughput2a
# 18  v1_throughput2a
# 19  v1_throughput2a
# 20  v1_throughput2a
# 21  v1_throughput2a
# 22  v1_throughput2a
# 23  v1_throughput2a
# 24  v1_throughput2a
# 25  v1_throughput2a
# 26  v1_throughput2a
# 27  v1_throughput2a
# 28  v1_throughput2a
# 29  v1_throughput2a
# 30  v1_throughput2a
# 31  v1_throughput2a
# 32  v1_throughput2a
# 33  v1_throughput2a
# 34  v1_throughput2a
# 35  v1_throughput2a
# 36  v1_throughput2a
# 37  v1_throughput2a
# 38  v1_throughput2a
# 39  v1_throughput2a
# 40  v1_throughput2a
# 41  v1_throughput2a
# 42  v1_throughput2a
# 43  v1_throughput2a
# 44  v1_throughput2a
# 45  v1_throughput2a
# 46  v1_throughput2a
# 47  v1_throughput2a
# 48  v1_throughput2a
# 49  v1_throughput2a

# %%
def make_jobs_df(array_list, JobName, JobId, Machine = 'cx1'):
    df = DataFrame(columns = ['JobId','ArrayId', 'Machine', 'JobName', 'User', 'Time', 'Status', 'Queue'])
    df.ArrayId = np.array(np.array(array_list))
    df.JobId = JobId
    df.Machine = Machine
    df.JobName = JobName
    return df


def read_logs(working_dir, jobs, errors = True, outputs = False):
    log_dir = working_dir / 'logs'
    for index, job in jobs.iterrows():
        output_file = log_dir / f'{job.JobName}.o{job.JobId}.{job.ArrayId}'
        error_file =  log_dir / f'{job.JobName}.e{job.JobId}.{job.ArrayId}'
        
        job_name = f'{job.JobId}[{job.ArrayId}].{job.Machine}'
        print(f'########## {job_name} ###############')
        if output_file.exists() and outputs: print(output_file.read_text())
        if error_file.exists() and errors: print(error_file.read_text())

def qsub(working_dir, jobs):
    '''Takes a dataframe of jobs'''
    log_dir = working_dir / 'logs'
    for index, job in jobs.iterrows():
        job_name = f'{job.JobId}[{job.ArrayId}].{job.Machine}'
        cmd_output = check_output(['qsub', '-J', f'{job.ArrayId}-{job.ArrayId + 1}:2', '../runscript.sh'], cwd = log_dir, encoding = 'utf8')
        print(f'starting {job_name}: {cmd_output}')

def qdel(jobs):    
    for index, job in jobs.iterrows():
        if job.ArrayId != '':
            job_name = f'{job.JobId}[{job.ArrayId}].{job.Machine}'
            cmd_output = check_output(['qdel', job_name])
            print(f'killing {job_name}: {cmd_output}')

# %%
jobs_to_start = make_jobs_df(
    array_list = [951, 952, 953, 954, 1056, 1057, 1058, 1059, 1060, 1463, 1464, 1837, 1838, 1839, 1840, 1904, 1965, 1966, 1967, 5123, 5266, 5267],
    JobName = 'phase_diagram_5',
    JobId = 2299532,
    Machine = 'cx1'
)
#read_logs(Path('./data/phase_diagram_5'), jobs_to_start)
#qsub(Path('./data/phase_diagram_5'), jobs_to_start)
# Out:
# starting 2299532[951].cx1: 2303204[].cx1
#
# starting 2299532[952].cx1: 2303205[].cx1
#
# starting 2299532[953].cx1: 2303206[].cx1
#
# starting 2299532[954].cx1: 2303207[].cx1
#
# starting 2299532[1056].cx1: 2303208[].cx1
#
# starting 2299532[1057].cx1: 2303209[].cx1
#
# starting 2299532[1058].cx1: 2303210[].cx1
#
# starting 2299532[1059].cx1: 2303211[].cx1
#
# starting 2299532[1060].cx1: 2303212[].cx1
#
# starting 2299532[1463].cx1: 2303213[].cx1
#
# starting 2299532[1464].cx1: 2303214[].cx1
#
# starting 2299532[1837].cx1: 2303215[].cx1
#
# starting 2299532[1838].cx1: 2303216[].cx1
#
# starting 2299532[1839].cx1: 2303217[].cx1
#
# starting 2299532[1840].cx1: 2303218[].cx1
#
# starting 2299532[1904].cx1: 2303219[].cx1
#
# starting 2299532[1965].cx1: 2303220[].cx1
#
# starting 2299532[1966].cx1: 2303221[].cx1
#
# starting 2299532[1967].cx1: 2303222[].cx1
#
# starting 2299532[5123].cx1: 2303223[].cx1
#
# starting 2299532[5266].cx1: 2303224[].cx1
#
# starting 2299532[5267].cx1: 2303225[].cx1

# %%
jobs = qstat()
jobs[jobs.Status == 'R']
# Out:
# Empty DataFrame
# Columns: [JobId, ArrayId, Machine, JobName, User, Time, Status, Queue]
# Index: []

# %%
jobs_to_start = pd.DataFrame(columns = ['JobId','ArrayId', 'Machine', 'JobName', 'User', 'Time', 'Status', 'Queue'])
jobs_to_start.ArrayId = np.array([727, 728, 729, 951, 952, 953, 954, 1056, 1057, 1058, 1059, 1060, 1463, 1464, 1837, 1838, 1839, 1840, 1904, 1965, 1966, 1967, 5123, 5266, 5267])

qsub(working_dir = Path('./data/phase_diagram_5'), jobs = to_kill)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-50aa4fcb193b> in <module>()
# ----> 1 qsub(working_dir = Path('./data/phase_diagram_5'), jobs = to_kill)
#
# <ipython-input-12-10b50a6d8b03> in qsub(working_dir, jobs)
#       2     '''Takes a dataframe of jobs'''
#       3     log_dir = working_dir / 'logs'
# ----> 4     for index, job in iterable:
#       5         cmd_output = check_output(['qsub', '-t', f'{job.ArrayId}-{job.ArrayId + 1}:2', 'runscript.sh'], cwd = log_dir)
#       6
#
# NameError: name 'iterable' is not defined

# %%
jobs
# Out:
#         JobId ArrayId Machine          JobName   User Time Status  \
# 0     2287114             cx1  phase_diagram_3  tch14    0      B
# 1     2287114       1     cx1  phase_diagram_3  tch14    0      X
# 2     2287114       2     cx1  phase_diagram_3  tch14    0      X
# 3     2287114       3     cx1  phase_diagram_3  tch14    0      X
# 4     2287114       4     cx1  phase_diagram_3  tch14    0      X
# 5     2287114       5     cx1  phase_diagram_3  tch14    0      X
# 6     2287114       6     cx1  phase_diagram_3  tch14    0      X
# 7     2287114       7     cx1  phase_diagram_3  tch14    0      X
# 8     2287114       8     cx1  phase_diagram_3  tch14    0      X
# 9     2287114       9     cx1  phase_diagram_3  tch14    0      X
# 10    2287114      10     cx1  phase_diagram_3  tch14    0      X
# 11    2287114      11     cx1  phase_diagram_3  tch14    0      X
# 12    2287114      12     cx1  phase_diagram_3  tch14    0      X
# 13    2287114      13     cx1  phase_diagram_3  tch14    0      X
# 14    2287114      14     cx1  phase_diagram_3  tch14    0      X
# 15    2287114      15     cx1  phase_diagram_3  tch14    0      X
# 16    2287114      16     cx1  phase_diagram_3  tch14    0      X
# 17    2287114      17     cx1  phase_diagram_3  tch14    0      X
# 18    2287114      18     cx1  phase_diagram_3  tch14    0      X
# 19    2287114      19     cx1  phase_diagram_3  tch14    0      X
# 20    2287114      20     cx1  phase_diagram_3  tch14    0      X
# 21    2287114      21     cx1  phase_diagram_3  tch14    0      X
# 22    2287114      22     cx1  phase_diagram_3  tch14    0      X
# 23    2287114      23     cx1  phase_diagram_3  tch14    0      X
# 24    2287114      24     cx1  phase_diagram_3  tch14    0      X
# 25    2287114      25     cx1  phase_diagram_3  tch14    0      X
# 26    2287114      26     cx1  phase_diagram_3  tch14    0      X
# 27    2287114      27     cx1  phase_diagram_3  tch14    0      X
# 28    2287114      28     cx1  phase_diagram_3  tch14    0      X
# 29    2287114      29     cx1  phase_diagram_3  tch14    0      X
# ...       ...     ...     ...              ...    ...  ...    ...
# 7471  2287114    7471     cx1  phase_diagram_3  tch14    0      X
# 7472  2287114    7472     cx1  phase_diagram_3  tch14    0      X
# 7473  2287114    7473     cx1  phase_diagram_3  tch14    0      X
# 7474  2287114    7474     cx1  phase_diagram_3  tch14    0      X
# 7475  2287114    7475     cx1  phase_diagram_3  tch14    0      X
# 7476  2287114    7476     cx1  phase_diagram_3  tch14    0      X
# 7477  2287114    7477     cx1  phase_diagram_3  tch14    0      X
# 7478  2287114    7478     cx1  phase_diagram_3  tch14    0      X
# 7479  2287114    7479     cx1  phase_diagram_3  tch14    0      X
# 7480  2287114    7480     cx1  phase_diagram_3  tch14    0      X
# 7481  2287114    7481     cx1  phase_diagram_3  tch14    0      X
# 7482  2287114    7482     cx1  phase_diagram_3  tch14    0      X
# 7483  2287114    7483     cx1  phase_diagram_3  tch14    0      X
# 7484  2287114    7484     cx1  phase_diagram_3  tch14    0      X
# 7485  2287114    7485     cx1  phase_diagram_3  tch14    0      X
# 7486  2287114    7486     cx1  phase_diagram_3  tch14    0      X
# 7487  2287114    7487     cx1  phase_diagram_3  tch14    0      X
# 7488  2287114    7488     cx1  phase_diagram_3  tch14    0      X
# 7489  2287114    7489     cx1  phase_diagram_3  tch14    0      X
# 7490  2287114    7490     cx1  phase_diagram_3  tch14    0      X
# 7491  2287114    7491     cx1  phase_diagram_3  tch14    0      X
# 7492  2287114    7492     cx1  phase_diagram_3  tch14    0      X
# 7493  2287114    7493     cx1  phase_diagram_3  tch14    0      X
# 7494  2287114    7494     cx1  phase_diagram_3  tch14    0      X
# 7495  2287114    7495     cx1  phase_diagram_3  tch14    0      X
# 7496  2287114    7496     cx1  phase_diagram_3  tch14    0      X
# 7497  2287114    7497     cx1  phase_diagram_3  tch14    0      X
# 7498  2287114    7498     cx1  phase_diagram_3  tch14    0      X
# 7499  2287114    7499     cx1  phase_diagram_3  tch14    0      X
# 7500  2287114    7500     cx1  phase_diagram_3  tch14    0      X
#
#                 Queue
# 0     v1_throughput2a
# 1     v1_throughput2a
# 2     v1_throughput2a
# 3     v1_throughput2a
# 4     v1_throughput2a
# 5     v1_throughput2a
# 6     v1_throughput2a
# 7     v1_throughput2a
# 8     v1_throughput2a
# 9     v1_throughput2a
# 10    v1_throughput2a
# 11    v1_throughput2a
# 12    v1_throughput2a
# 13    v1_throughput2a
# 14    v1_throughput2a
# 15    v1_throughput2a
# 16    v1_throughput2a
# 17    v1_throughput2a
# 18    v1_throughput2a
# 19    v1_throughput2a
# 20    v1_throughput2a
# 21    v1_throughput2a
# 22    v1_throughput2a
# 23    v1_throughput2a
# 24    v1_throughput2a
# 25    v1_throughput2a
# 26    v1_throughput2a
# 27    v1_throughput2a
# 28    v1_throughput2a
# 29    v1_throughput2a
# ...               ...
# 7471  v1_throughput2a
# 7472  v1_throughput2a
# 7473  v1_throughput2a
# 7474  v1_throughput2a
# 7475  v1_throughput2a
# 7476  v1_throughput2a
# 7477  v1_throughput2a
# 7478  v1_throughput2a
# 7479  v1_throughput2a
# 7480  v1_throughput2a
# 7481  v1_throughput2a
# 7482  v1_throughput2a
# 7483  v1_throughput2a
# 7484  v1_throughput2a
# 7485  v1_throughput2a
# 7486  v1_throughput2a
# 7487  v1_throughput2a
# 7488  v1_throughput2a
# 7489  v1_throughput2a
# 7490  v1_throughput2a
# 7491  v1_throughput2a
# 7492  v1_throughput2a
# 7493  v1_throughput2a
# 7494  v1_throughput2a
# 7495  v1_throughput2a
# 7496  v1_throughput2a
# 7497  v1_throughput2a
# 7498  v1_throughput2a
# 7499  v1_throughput2a
# 7500  v1_throughput2a
#
# [7501 rows x 8 columns]

# %%
from collections import Counter
j = job_summary(qstat())
for name, jobs in j.groupby(level=0):
    statuses, nums = np.array([[status, job.ArrayId] for status, job in jobs.groupby(level=1)]).T
    N = 20
    nums = N * np.round(nums / np.sum(nums))
    nums[-1] -= (np.sum(nums) - N)
    print(nums)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-115-6a6b6b8c1981> in <module>()
#       2 j = job_summary(qstat())
#       3 for name, jobs in j.groupby(level=0):
# ----> 4     statuses, nums = np.array([[status, job.ArrayId] for status, *job in jobs.groupby(level=1)]).T
#       5     N = 20
#       6     nums = N * np.round(nums / np.sum(nums))
#
# <ipython-input-115-6a6b6b8c1981> in <listcomp>(.0)
#       2 j = job_summary(qstat())
#       3 for name, jobs in j.groupby(level=0):
# ----> 4     statuses, nums = np.array([[status, job.ArrayId] for status, *job in jobs.groupby(level=1)]).T
#       5     N = 20
#       6     nums = N * np.round(nums / np.sum(nums))
#
# AttributeError: 'list' object has no attribute 'ArrayId'

# %%
# Out:
# True

# %%
from slackclient import SlackClient

def slack_message(message, channel):
    token = 'xoxp-525787134705-526388674674-526594178197-c5b1337fd7ba764c07a787297720f650'
    sc = SlackClient(token)

    sc.api_call('chat.postMessage', channel=channel, 
                text=message, username='CMTH bot',
                icon_emoji=':robot_face:')
    
import time
last_qstat = qstat()
while True:
    time.sleep(10)
    print('Checking qstat')
    q = qstat()
    if not q.equals(last_qstat):
        summary = job_summary(qstat())
        slack_message(summary.to_string(), 'bots-notifications')
        last_qstat = q
# Out:
# Checking qstat
# Checking qstat
# Checking qstat
# Checking qstat
# Checking qstat
# Checking qstat
# Checking qstat
# Checking qstat
# Checking qstat
# Checking qstat
# Checking qstat
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-82-1493b54343d5> in <module>()
#      12 last_qstat = qstat()
#      13 while True:
# ---> 14     time.sleep(10)
#      15     print('Checking qstat')
#      16     q = qstat()
#
# KeyboardInterrupt:
