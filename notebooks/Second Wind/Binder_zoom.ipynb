# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
import timeit
import h5py
from pathlib import Path
import numpy as np
from itertools import product
import pickle
import scipy.special
import scipy.stats
from math import exp
import multiprocessing
import functools

from montecarlo import *

# %matplotlib inline
np.seterr(all='warn')
textwidth = 6.268
mpl.rcParams['figure.dpi'] = 70
default_figargs = dict(figsize = (textwidth,textwidth))

from montecarlo import *

# %% [markdown]
# To check the sanity of the monte carlo routine, the above plot compares the boltzman factor $exp(-\beta F) $ for each state of a small system (N=6) with the number of occurances seen during a monte carlo run. Each column shows these factors after an increasing number of montecarlo steps. Each row represents the states by a differnt measure, first they're simply ordered by increasing free energy, second they're plotted against free energy so that degernate states clump together. The 3rd and 4th show the overall occupation $Nf + Nc$ and the squared staggered magnetisation.

# %% [markdown]
# The above plot shows the mean of each observable after x monte carlo steps, showing gradual convergence. Currently the Ff, Fc and Nc observables don't converge to the correct values!

# %%
# %%time
from direct_partition_functions import binder_parrallel
from time import time
n_cumulants = 5
T = np.linspace(1.5, 4, 20)
beta = 1/T
Ns = [8,12,14,16,18,20]
Us = [10,]
Js = [10,]
t = 1
alpha = 1.5
binder_params = dict(t = t, alpha = alpha, mu = 0, beta = None, J = None, U = None, normalise = True)
# Out:
# CPU times: user 1.47 ms, sys: 224 µs, total: 1.69 ms
# Wall time: 1.48 ms

# %%
binder_cumulants = np.ones(shape = (len(Js), len(Us), len(Ns), 2, n_cumulants, len(beta)), dtype = np.float64)
with multiprocessing.Pool(multiprocessing.cpu_count() - 2) as pool:
    for slice1, J in zip(binder_cumulants, Js):
        for slice2, U in zip(slice1, Us):
            for slice3, system_size in zip(slice2, Ns):
                t0 = time()
                result = np.array([binder_parrallel(system_size = system_size, mu = 0, beta = b, U = U, J = J, t = t, alpha = alpha, pool=pool) for b in beta])
                np.copyto(slice3, np.einsum('ijk->jki',result))
                print(system_size, U, J, f'in {time() - t0:.0f} seconds')

np.savez('./pickled_data/binder_cumulants_direct_zoom.npz', 
         T=T, Ns=Ns, Us=Us, Js = Js, n_cumulants=n_cumulants, t=t, alpha = alpha, beta = beta,
         binder_cumulants=binder_cumulants)
print('done')
# Out:
# 8 10 10 in 0 seconds
# 12 10 10 in 4 seconds
# 14 10 10 in 15 seconds
# 16 10 10 in 62 seconds
# 18 10 10 in 258 seconds
# 20 10 10 in 1463 seconds
# done
# CPU times: user 17min 28s, sys: 1min 17s, total: 18min 46s
# Wall time: 30min 3s

# %%
#%%time
from time import time
from montecarlo import *
N_steps = int(100 * 1000)
N_burn_in = int(1 * 1000)

MCMC_params = dict(
        N_steps = N_steps, N_burn_in = N_burn_in, 
        logger = Magnetisation_cumulants(N_cumulants = n_cumulants),
        proposal = p_multi_site_uniform_reflect,
        #proposal_args = dict(lam = 4),
        accept_function = perturbation_accept,
    )

T = np.linspace(1.5, 4, 15)
Ns = [8,12,14,16,18,20]
beta = 1/T

def compute(beta, **kwargs):
    kwargs['parameters']['beta'] = beta
    return FK_mcmc_2(**kwargs)


mcmc_binder_cumulants = np.zeros(shape = (len(Js), len(Us), len(Ns), 2, n_cumulants, len(beta)), dtype = np.float64)
with multiprocessing.Pool(multiprocessing.cpu_count() - 2) as pool:
    for slice1, J in zip(mcmc_binder_cumulants, Js):
        for slice2, U in zip(slice1, Us):
            for slice3, system_size in zip(slice2, Ns):
                t0 = time()
                binder_params.update(J=J, U=U)
                MCMC_params.update(state=np.arange(system_size)%2)
                
                curried = functools.partial(compute, parameters = binder_params, **MCMC_params)
                
                result = pool.map(curried, beta)
                #(beta, [non_central/central], powers) -> ([non_central/central], powers, beta)
                np.copyto(slice3, np.einsum('ijk->jki',result))
                print(U, J, system_size, f'{time() - t0:.0f} seconds')

np.savez('./pickled_data/binder_cumulants_mcmc_zoom_3.npz', 
         N_steps = N_steps, N_burn_in = N_burn_in, mc_beta=beta, mcmc_Ns = Ns,
         mcmc_binder_cumulants = mcmc_binder_cumulants)
print('done!')
# Out:
# Warning, p_acc = 0.12465222772277228, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.6666666666666666, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.12199133663366336, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.45161290322580644, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.12320049504950495, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.5384615384615384, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.12256559405940594, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.4912280701754386, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.12188861386138614, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.417910447761194, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.12640346534653465, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.36363636363636365, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.12416584158415842, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.5957446808510638, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.12349628712871287, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.38888888888888895, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.13700990099009902, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3218390804597701, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.15409653465346534, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.28865979381443296, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.13080940594059406, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3414634146341463, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.14423886138613862, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.30434782608695654, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.1630928217821782, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.27450980392156865, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.1865730198019802, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.25, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.17498514851485147, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.2616822429906542, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# 10 10 8 212 seconds
# Warning, p_acc = 0.08228300330033003, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.6666666666666666, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.07991419141914191, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.5384615384615384, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.08143729372937293, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.5957446808510638, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.07841996699669967, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.4912280701754386, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.07671287128712871, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.45161290322580644, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.07450660066006601, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.38888888888888895, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.0757970297029703, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.417910447761194, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.07574752475247525, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.36363636363636365, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.07772194719471948, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3414634146341463, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.08942739273927393, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.30434782608695654, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.08292739273927392, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3218390804597701, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.09786386138613862, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.28865979381443296, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.10753217821782178, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.27450980392156865, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.13008003300330034, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.25, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.11856930693069306, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.2616822429906542, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# 10 10 12 287 seconds
# Warning, p_acc = 0.06425318246110326, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.45161290322580644, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.06932178217821783, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.5957446808510638, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.06542644978783593, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.4912280701754386, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.06805304101838755, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.5384615384615384, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.062246110325318245, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.417910447761194, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.0697956152758133, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.6666666666666666, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.06064568599717115, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.38888888888888895, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.06354243281471005, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3414634146341463, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.060878359264497875, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.36363636363636365, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.06743210749646393, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3218390804597701, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.07379066478076379, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.30434782608695654, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.09118033946251768, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.27450980392156865, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.08154031117397453, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.28865979381443296, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.1026973125884017, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.2616822429906542, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.11331541725601131, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.25, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# 10 10 14 318 seconds
# Warning, p_acc = 0.05656930693069307, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.4912280701754386, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.06018997524752475, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.5957446808510638, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.06061509900990099, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.6666666666666666, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05902227722772277, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.5384615384615384, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05235024752475247, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.417910447761194, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05135334158415841, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.38888888888888895, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05436200495049505, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.45161290322580644, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.050961014851485145, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.36363636363636365, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05272957920792079, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3414634146341463, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.0557134900990099, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3218390804597701, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.06051918316831683, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.30434782608695654, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.06946596534653465, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.28865979381443296, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.07816398514851484, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.27450980392156865, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.08985334158415842, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.2616822429906542, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.1004325495049505, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.25, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# 10 10 16 359 seconds
# Warning, p_acc = 0.05236523652365237, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.5384615384615384, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.04828107810781078, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.45161290322580644, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.0539939493949395, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.5957446808510638, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05384543454345435, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.6666666666666666, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.04613861386138614, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.417910447761194, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05058580858085809, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.4912280701754386, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.04322277227722772, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.36363636363636365, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.044656215621562155, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3414634146341463, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.04372277227722772, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.38888888888888895, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.04705720572057206, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3218390804597701, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.051942244224422444, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.30434782608695654, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05814796479647965, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.28865979381443296, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.06764081408140814, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.27450980392156865, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.09006215621562157, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.25, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.07829482948294829, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.2616822429906542, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# 10 10 18 399 seconds
# Warning, p_acc = 0.038, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.36363636363636365, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.03799059405940594, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.38888888888888895, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.044366831683168316, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.4912280701754386, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.04196089108910891, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.45161290322580644, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.048544554455445546, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.6666666666666666, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.03997722772277228, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.417910447761194, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.04627574257425743, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.5384615384615384, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.037830693069306934, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3414634146341463, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.04796930693069307, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.5957446808510638, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.039812376237623764, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3218390804597701, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.04432574257425743, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.30434782608695654, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05183762376237624, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.28865979381443296, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.0580470297029703, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.27450980392156865, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.06946881188118811, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.2616822429906542, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.08099207920792079, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.25, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# 10 10 20 446 seconds
# done!

# %%
#%%time
from itertools import count
data = np.load('./pickled_data/binder_cumulants_direct_zoom_huge.npz')
locals().update(data)
data = np.load('./pickled_data/binder_cumulants_mcmc_zoom_3.npz')
locals().update(data)

def binder_cumulant(central_moments): return 1 - central_moments[4]/(3*central_moments[2]**2)

f, axes = plt.subplots(len(Js),len(Us),figsize = (len(Js)*15,len(Us)*15), sharex = 'col', sharey = 'row', gridspec_kw = dict(hspace = 0, wspace = 0), squeeze = False)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
lines = np.zeros(shape = Ns.shape[0], dtype = object)

for row, mc_slice1, dir_slice1, J in zip(axes, mcmc_binder_cumulants, binder_cumulants, Js):
    for ax, mc_slice2, dir_slice2, U in zip(row, mc_slice1, dir_slice1, Us):
        for i, dir_slice3, system_size in zip(count(), dir_slice2, Ns):
            dir_Mf_moments, dir_Mf_central_moments = dir_slice3
            dir_binder_cumulant = binder_cumulant(dir_Mf_central_moments)
            lines[i], = ax.plot(T, dir_binder_cumulant, label = f'N = {system_size}')    

        for i, mc_slice3, system_size in zip(count(), mc_slice2, mcmc_Ns):
            mc_Mf_moments, mc_Mf_central_moments = mc_slice3
            ax.scatter(1/mc_beta, binder_cumulant(mc_Mf_central_moments), marker='.')
            
        ax.set(xlim = (1.5,4))
        ax.legend()

f.suptitle('Binder Cumulant against Temperature')

for ax,U in zip(axes[0],Us): ax.set(title = f'U = {U}') 
for ax,J in zip(axes.T[0], Js): ax.set(ylabel = f'J = {J}\n Binder Cumulant') 
for ax in axes[-1]: ax.set(xlabel = 'T')
