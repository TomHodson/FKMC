# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
import timeit
import h5py
from pathlib import Path
import numpy as np
from itertools import product
import pickle
import scipy.special
import scipy.stats
from math import exp
import multiprocessing
import functools

from montecarlo import *

# %matplotlib inline
np.seterr(all='warn')
textwidth = 6.268
mpl.rcParams['figure.dpi'] = 70
default_figargs = dict(figsize = (textwidth,textwidth))

from montecarlo import *

# %% [markdown]
# To check the sanity of the monte carlo routine, the above plot compares the boltzman factor $exp(-\beta F) $ for each state of a small system (N=6) with the number of occurances seen during a monte carlo run. Each column shows these factors after an increasing number of montecarlo steps. Each row represents the states by a differnt measure, first they're simply ordered by increasing free energy, second they're plotted against free energy so that degernate states clump together. The 3rd and 4th show the overall occupation $Nf + Nc$ and the squared staggered magnetisation.

# %% [markdown]
# The above plot shows the mean of each observable after x monte carlo steps, showing gradual convergence. Currently the Ff, Fc and Nc observables don't converge to the correct values!

# %%
# %%time
from direct_partition_functions import binder_parrallel
from time import time
n_cumulants = 5
T = np.linspace(1.5, 4, 20)
beta = 1/T
Ns = [8,12,14,16,18,20]
Us = [10,]
Js = [10,]
t = 1
alpha = 1.5
binder_params = dict(t = t, alpha = alpha, mu = 0, beta = None, J = None, U = None, normalise = True)

binder_cumulants = np.ones(shape = (len(Js), len(Us), len(Ns), 2, n_cumulants, len(beta)), dtype = np.float64)
with multiprocessing.Pool(multiprocessing.cpu_count() - 2) as pool:
    for slice1, J in zip(binder_cumulants, Js):
        for slice2, U in zip(slice1, Us):
            for slice3, system_size in zip(slice2, Ns):
                t0 = time()
                result = np.array([binder_parrallel(system_size = system_size, mu = 0, beta = b, U = U, J = J, t = t, alpha = alpha, pool=pool) for b in beta])
                np.copyto(slice3, np.einsum('ijk->jki',result))
                print(system_size, U, J, f'in {time() - t0:.0f} seconds')

np.savez('./pickled_data/binder_cumulants_direct_zoom.npz', 
         T=T, Ns=Ns, Us=Us, Js = Js, n_cumulants=n_cumulants, t=t, alpha = alpha, beta = beta,
         binder_cumulants=binder_cumulants)
print('done')
# Out:
# 8 10 10 in 0 seconds
# 12 10 10 in 4 seconds
# 14 10 10 in 15 seconds
# 16 10 10 in 62 seconds
# 18 10 10 in 258 seconds
# 20 10 10 in 1463 seconds
# done
# CPU times: user 17min 28s, sys: 1min 17s, total: 18min 46s
# Wall time: 30min 3s

# %%
#%%time
from time import time
from montecarlo import *
N_steps = int(50 * 1000)
N_burn_in = int(1 * 1000)

MCMC_params = dict(
        N_steps = N_steps, N_burn_in = N_burn_in, 
        state=np.arange(system_size)%2, 
        logger = Magnetisation_cumulants(N_cumulants = n_cumulants),
        proposal = p_multi_site_uniform_reflect,
        #proposal_args = dict(lam = 4),
        accept_function = simple_accept,
    )

T = np.linspace(1.5, 4, 10)
Ns = [8,12,14,16,18,20]
beta = 1/T

def compute(beta, **kwargs):
    kwargs['parameters']['beta'] = beta
    return FK_mcmc_2(**kwargs)


mcmc_binder_cumulants = np.zeros(shape = (len(Js), len(Us), len(Ns), 2, n_cumulants, len(beta)), dtype = np.float64)
with multiprocessing.Pool(multiprocessing.cpu_count() - 2) as pool:
    for slice1, J in zip(mcmc_binder_cumulants, Js):
        for slice2, U in zip(slice1, Us):
            for slice3, system_size in zip(slice2, Ns):
                t0 = time()
                binder_params.update(J=J, U=U)
                
                curried = functools.partial(compute, parameters = binder_params, **MCMC_params)
                
                result = pool.map(curried, beta)
                #(beta, [non_central/central], powers) -> ([non_central/central], powers, beta)
                np.copyto(slice3, np.einsum('ijk->jki',result))
                print(U, J, system_size, f'{time() - t0:.0f} seconds')

np.savez('./pickled_data/binder_cumulants_mcmc_zoom_2.npz', 
         N_steps = N_steps, N_burn_in = N_burn_in, mc_beta=beta, mcmc_Ns = Ns,
         mcmc_binder_cumulants = mcmc_binder_cumulants)
print('done!')
# Out:
# Warning, p_acc = 0.05055686274509804, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.6666666666666666, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.060085294117647056, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3829787234042553, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05226666666666667, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.4864864864864865, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05475686274509804, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.42857142857142855, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05118039215686274, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.5625, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.07194019607843137, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.34615384615384615, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.15779607843137256, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.26865671641791045, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.08950098039215686, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3157894736842105, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.12227156862745098, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.29032258064516125, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# 10 10 8 412 seconds
# Warning, p_acc = 0.054807843137254904, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.42857142857142855, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.060096078431372546, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3829787234042553, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05010392156862745, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.6666666666666666, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05205294117647059, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.4864864864864865, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.07138529411764706, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.34615384615384615, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.050584313725490195, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.5625, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.1171078431372549, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.29032258064516125, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.09415490196078431, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3157894736842105, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.16284019607843137, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.26865671641791045, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# 10 10 12 618 seconds
# Warning, p_acc = 0.058947058823529415, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3829787234042553, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.07088235294117647, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.34615384615384615, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.054191176470588236, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.42857142857142855, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05093921568627451, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.5625, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05061862745098039, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.6666666666666666, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.051930392156862744, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.4864864864864865, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.08981470588235294, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3157894736842105, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.12221862745098039, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.29032258064516125, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.15960980392156862, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.26865671641791045, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# 10 10 14 619 seconds
# Warning, p_acc = 0.05892450980392157, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3829787234042553, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05083137254901961, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.5625, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05017941176470588, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.6666666666666666, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.054526470588235294, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.42857142857142855, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.07170588235294117, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.34615384615384615, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05193137254901961, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.4864864864864865, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.08995294117647058, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3157894736842105, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.1992392156862745, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.25, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.11955588235294118, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.29032258064516125, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.15997745098039215, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.26865671641791045, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# 10 10 16 613 seconds
# Warning, p_acc = 0.050040196078431375, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.6666666666666666, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.051941176470588234, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.4864864864864865, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05046470588235294, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.5625, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.07153921568627451, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.34615384615384615, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.0541, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.42857142857142855, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05929901960784314, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3829787234042553, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.09182549019607843, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3157894736842105, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.16138333333333332, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.26865671641791045, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.11998039215686275, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.29032258064516125, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# 10 10 18 424 seconds
# Warning, p_acc = 0.054381372549019605, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.42857142857142855, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.0692313725490196, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.34615384615384615, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05077843137254902, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.5625, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05235882352941176, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.4864864864864865, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.0592656862745098, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3829787234042553, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.05023627450980392, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.6666666666666666, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.08970490196078432, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.3157894736842105, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.16046470588235295, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.26865671641791045, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# Warning, p_acc = 0.1228264705882353, {'t': 1, 'alpha': 1.5, 'mu': 0, 'beta': 0.29032258064516125, 'J': 10, 'U': 10, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# 10 10 20 385 seconds
# done!

# %%
#%%time
from itertools import count
data = np.load('./pickled_data/binder_cumulants_direct_zoom_huge.npz')
locals().update(data)
data = np.load('./pickled_data/binder_cumulants_mcmc_zoom_2.npz')
locals().update(data)

def binder_cumulant(central_moments): return 1 - central_moments[4]/(3*central_moments[2]**2)

f, axes = plt.subplots(len(Js),len(Us),figsize = (len(Js)*15,len(Us)*15), sharex = 'col', sharey = 'row', gridspec_kw = dict(hspace = 0, wspace = 0), squeeze = False)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
lines = np.zeros(shape = Ns.shape[0], dtype = object)

for row, mc_slice1, dir_slice1, J in zip(axes, mcmc_binder_cumulants, binder_cumulants, Js):
    for ax, mc_slice2, dir_slice2, U in zip(row, mc_slice1, dir_slice1, Us):
        for i, dir_slice3, system_size in zip(count(), dir_slice2, Ns):
            dir_Mf_moments, dir_Mf_central_moments = dir_slice3
            dir_binder_cumulant = binder_cumulant(dir_Mf_central_moments)
            lines[i], = ax.plot(T, dir_binder_cumulant, label = f'N = {system_size}')    

        for i, mc_slice3, system_size in zip(count(), mc_slice2, mcmc_Ns):
            mc_Mf_moments, mc_Mf_central_moments = mc_slice3
            ax.scatter(1/mc_beta, binder_cumulant(mc_Mf_central_moments), marker='.')
            
        ax.set(xlim = (1.5,4))
        ax.legend()

f.suptitle('Binder Cumulant against Temperature')

for ax,U in zip(axes[0],Us): ax.set(title = f'U = {U}') 
for ax,J in zip(axes.T[0], Js): ax.set(ylabel = f'J = {J}\n Binder Cumulant') 
for ax in axes[-1]: ax.set(xlabel = 'T')
