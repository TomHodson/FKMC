# %%
## print('Starting generic python imports')
from pathlib import Path
import numpy as np
import os
from time import time, sleep
import sys
from munch import Munch

print('Doing FKMC imports')
from FKMC.montecarlo import *

## overall input parameters
repeats = 10
Ts = [100, 50, 10, 5, 3, 2, 1, 0.1]
Ns = np.logspace(np.log10(35), np.log10(250), 10, dtype = np.int) // 5 * 5
J = 5
U = 5
alpha = 1.25

initial_states_cycle = [
    #lambda N: np.arange(N, dtype = np.float64) % 2,
    #lambda N: np.zeros(N, dtype = np.float64),
    lambda N: np.random.choice(np.array([0,1], dtype = np.float64), size = N),
]

total_jobs = len(Ts) * repeats * len(initial_states_cycle)

#give information to the dispatch script
batch_params = Munch(total_jobs = total_jobs, repeats = repeats, Ts = Ts, structure_names = ('repeats', 'initial_state', 'Ts'))

print('Getting environment variables')
slurm_job_id = int(os.getenv('SLURM_ARRAY_JOB_ID', -1))
slurm_task_id = int(os.getenv('SLURM_ARRAY_TASK_ID', 11))
max_slurm_task_id = int(os.getenv('SLURM_ARRAY_TASK_MAX', total_jobs - 1))
working_dir = Path(".")

##sleep if necessary3-400
debug = (slurm_job_id == -1)
sleeptime = np.random.random() * (30)
print(f'Waiting for {sleeptime:.0f} seconds to randomise the finish time')
if not debug: sleep(sleeptime)


##using the value of slurm_task_id, decide what parameters this job will have
T_i, j = slurm_task_id % len(Ts), slurm_task_id // len(Ts)
state_i, repeat_i = j % len(initial_states_cycle), j // len(initial_states_cycle)

T = Ts[T_i]
make_initial_state = initial_states_cycle[state_i]

print(f'T_i = {T_i}, repeat_i = {repeat_i}, state_i = {state_i}')
print(f'total_jobs = {total_jobs} max_slurm_task_id = {max_slurm_task_id}')

logs = np.empty(shape = len(Ns), dtype = object)

for i, N in enumerate(Ns):
    parameters = dict(t = 1, alpha = alpha, mu = 0, beta = 1/T, J = J, U = U, normalise = True)
    MCMC_params = dict(
            state = make_initial_state(N),
            N_steps = int(5e4) if not debug else 100,
            N_burn_in = int(1e3) if not debug else 0,
            thin = 100 if not debug else 1,
            logger = Eigenspectrum_IPR_all(bins = 2000, limit = 20),
            proposal = p_multi_site_uniform_reflect,
            accept_function = perturbation_accept,
            warnings = True,
        )

    print(f'starting N = {N}')
    t0 = time()
    logs[i] = FK_mcmc(**MCMC_params, parameters = parameters)
    logs[i].time = time() - t0

    parameters['J_matrix'] = '...'
    MCMC_params['state'] = '...'
    print(f'''
    params = {parameters},
    mc_params = {MCMC_params}
    ''')

    filename = f'{slurm_task_id}.npz'

    print(f'{time() - t0:.0f} seconds, saving in {filename}')

    if not debug: np.savez_compressed(working_dir/filename, 
        Ns = Ns, Ts = Ts, parameters = parameters, MCMC_params = MCMC_params, logs = logs, allow_pickle = True,
        desc = ''
        )
        
print('done')
# Out:
# Doing FKMC imports
# Getting environment variables
# Waiting for 16 seconds to randomise the finish time
# T_i = 3, repeat_i = 1, state_i = 0
# total_jobs = 80 max_slurm_task_id = 79
# starting N = 35
# 0% through after 0.00m
# 10% through after 0.00m
# 20% through after 0.00m
# 30% through after 0.00m
# 40% through after 0.00m
# 50% through after 0.01m
# 60% through after 0.01m
# 70% through after 0.01m
# 80% through after 0.01m
# 90% through after 0.01m
#
#     params = {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.2, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': '...'},
#     mc_params = {'state': '...', 'N_steps': 100, 'N_burn_in': 0, 'thin': 1, 'logger': <FKMC.montecarlo.Eigenspectrum_IPR_all object at 0x7f7b8b4f29b0>, 'proposal': <function p_multi_site_uniform_reflect at 0x7f7b730b22f0>, 'accept_function': <function perturbation_accept at 0x7f7b730b2620>, 'warnings': True}
#
# 1 seconds, saving in 11.npz
# starting N = 40
# 0% through after 0.00m
# 10% through after 0.00m
# 20% through after 0.00m
# 30% through after 0.00m
# 40% through after 0.00m
# 50% through after 0.01m
# 60% through after 0.01m
# 70% through after 0.01m
# 80% through after 0.01m
# 90% through after 0.01m
#
#     params = {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.2, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': '...'},
#     mc_params = {'state': '...', 'N_steps': 100, 'N_burn_in': 0, 'thin': 1, 'logger': <FKMC.montecarlo.Eigenspectrum_IPR_all object at 0x7f7b8b45fbe0>, 'proposal': <function p_multi_site_uniform_reflect at 0x7f7b730b22f0>, 'accept_function': <function perturbation_accept at 0x7f7b730b2620>, 'warnings': True}
#
# 1 seconds, saving in 11.npz
# starting N = 50
# 0% through after 0.00m
# 10% through after 0.00m
# 20% through after 0.00m
# 30% through after 0.00m
# 40% through after 0.01m
# 50% through after 0.01m
# 60% through after 0.01m
# 70% through after 0.01m
# 80% through after 0.01m
# 90% through after 0.01m
#
#     params = {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.2, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': '...'},
#     mc_params = {'state': '...', 'N_steps': 100, 'N_burn_in': 0, 'thin': 1, 'logger': <FKMC.montecarlo.Eigenspectrum_IPR_all object at 0x7f7b74062f98>, 'proposal': <function p_multi_site_uniform_reflect at 0x7f7b730b22f0>, 'accept_function': <function perturbation_accept at 0x7f7b730b2620>, 'warnings': True}
#
# 1 seconds, saving in 11.npz
# starting N = 65
# 0% through after 0.00m
# 10% through after 0.00m
# 20% through after 0.01m
# 30% through after 0.01m
# 40% through after 0.01m
# 50% through after 0.02m
# 60% through after 0.02m
# 70% through after 0.02m
# 80% through after 0.03m
# 90% through after 0.03m
#
#     params = {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.2, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': '...'},
#     mc_params = {'state': '...', 'N_steps': 100, 'N_burn_in': 0, 'thin': 1, 'logger': <FKMC.montecarlo.Eigenspectrum_IPR_all object at 0x7f7b8b469898>, 'proposal': <function p_multi_site_uniform_reflect at 0x7f7b730b22f0>, 'accept_function': <function perturbation_accept at 0x7f7b730b2620>, 'warnings': True}
#
# 2 seconds, saving in 11.npz
# starting N = 80
# 0% through after 0.00m
# 10% through after 0.01m
# 20% through after 0.01m
# 30% through after 0.01m
# 40% through after 0.02m
# 50% through after 0.02m
# 60% through after 0.03m
# 70% through after 0.03m
# 80% through after 0.04m
# 90% through after 0.04m
#
#     params = {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.2, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': '...'},
#     mc_params = {'state': '...', 'N_steps': 100, 'N_burn_in': 0, 'thin': 1, 'logger': <FKMC.montecarlo.Eigenspectrum_IPR_all object at 0x7f7bb1357320>, 'proposal': <function p_multi_site_uniform_reflect at 0x7f7b730b22f0>, 'accept_function': <function perturbation_accept at 0x7f7b730b2620>, 'warnings': True}
#
# 3 seconds, saving in 11.npz
# starting N = 100
# 0% through after 0.00m
# 10% through after 0.01m
# 20% through after 0.01m
# 30% through after 0.02m
# 40% through after 0.03m
# 50% through after 0.04m
# 60% through after 0.04m
# 70% through after 0.05m
# 80% through after 0.06m
# 90% through after 0.06m
# Warning, p_acc = 0.1989, {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.2, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
#
#     params = {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.2, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': '...'},
#     mc_params = {'state': '...', 'N_steps': 100, 'N_burn_in': 0, 'thin': 1, 'logger': <FKMC.montecarlo.Eigenspectrum_IPR_all object at 0x7f7b72716978>, 'proposal': <function p_multi_site_uniform_reflect at 0x7f7b730b22f0>, 'accept_function': <function perturbation_accept at 0x7f7b730b2620>, 'warnings': True}
#
# 4 seconds, saving in 11.npz
# starting N = 125
# 0% through after 0.00m
# 10% through after 0.02m
# 20% through after 0.03m
# 30% through after 0.04m
# 40% through after 0.06m
# 50% through after 0.08m
# 60% through after 0.09m
# 70% through after 0.11m
# 80% through after 0.13m
# 90% through after 0.15m
#
#     params = {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.2, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': '...'},
#     mc_params = {'state': '...', 'N_steps': 100, 'N_burn_in': 0, 'thin': 1, 'logger': <FKMC.montecarlo.Eigenspectrum_IPR_all object at 0x7f7b72716f60>, 'proposal': <function p_multi_site_uniform_reflect at 0x7f7b730b22f0>, 'accept_function': <function perturbation_accept at 0x7f7b730b2620>, 'warnings': True}
#
# 10 seconds, saving in 11.npz
# starting N = 160
# 0% through after 0.00m
# 10% through after 0.02m
# 20% through after 0.04m
# 30% through after 0.06m
# 40% through after 0.09m
# 50% through after 0.11m
# 60% through after 0.13m
# 70% through after 0.16m
# 80% through after 0.19m
# 90% through after 0.22m
# Warning, p_acc = 0.1505625, {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.2, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
#
#     params = {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.2, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': '...'},
#     mc_params = {'state': '...', 'N_steps': 100, 'N_burn_in': 0, 'thin': 1, 'logger': <FKMC.montecarlo.Eigenspectrum_IPR_all object at 0x7f7b72716390>, 'proposal': <function p_multi_site_uniform_reflect at 0x7f7b730b22f0>, 'accept_function': <function perturbation_accept at 0x7f7b730b2620>, 'warnings': True}
#
# 15 seconds, saving in 11.npz
# starting N = 200
# 0% through after 0.00m
# 10% through after 0.05m
# 20% through after 0.10m
# 30% through after 0.15m
# 40% through after 0.19m
# 50% through after 0.25m
# 60% through after 0.30m
# 70% through after 0.34m
# 80% through after 0.38m
# 90% through after 0.44m
# Warning, p_acc = 0.1366, {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.2, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
#
#     params = {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.2, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': '...'},
#     mc_params = {'state': '...', 'N_steps': 100, 'N_burn_in': 0, 'thin': 1, 'logger': <FKMC.montecarlo.Eigenspectrum_IPR_all object at 0x7f7b72716fd0>, 'proposal': <function p_multi_site_uniform_reflect at 0x7f7b730b22f0>, 'accept_function': <function perturbation_accept at 0x7f7b730b2620>, 'warnings': True}
#
# 29 seconds, saving in 11.npz
# starting N = 245
# 0% through after 0.00m
# 10% through after 0.12m
# 20% through after 0.23m
# 30% through after 0.36m
# 40% through after 0.45m
# 50% through after 0.56m
# 60% through after 0.65m
# 70% through after 0.78m
# 80% through after 0.91m
# 90% through after 1.02m
# Warning, p_acc = 0.193265306122449, {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.2, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
#
#     params = {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.2, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': '...'},
#     mc_params = {'state': '...', 'N_steps': 100, 'N_burn_in': 0, 'thin': 1, 'logger': <FKMC.montecarlo.Eigenspectrum_IPR_all object at 0x7f7b72713b70>, 'proposal': <function p_multi_site_uniform_reflect at 0x7f7b730b22f0>, 'accept_function': <function perturbation_accept at 0x7f7b730b2620>, 'warnings': True}
#
# 68 seconds, saving in 11.npz
# done
