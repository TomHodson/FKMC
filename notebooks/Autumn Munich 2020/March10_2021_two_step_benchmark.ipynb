# %%
## print('Starting generic python imports')
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import numpy as np
import os
from time import time, sleep
import sys
from munch import Munch
from itertools import product, islice
from FKMC.montecarlo_benchmark import *

## overall input parameters
T = 1.5
J = 5
U = 5
Ns = [300]
make_initial_state = lambda N: np.arange(N, dtype = np.float64) % 2 #a CDW initial state

alpha = 1.25
jobdir = Path('~/HPC_data/local_run_data/benchmark_run').expanduser()
jobdir.mkdir(parents=False, exist_ok=True)

logs = np.empty(shape = len(Ns), dtype = object)
previous_states = [make_initial_state(N) for N in Ns]
t1 = time()

for j in range(10):
    print(f"On round j = {j}")
    for i, N in enumerate(Ns):
        print(f'Starting N = {N}')
        parameters = dict(t = 1, alpha = alpha, mu = 0, beta = 1/T, J = J, U = U, normalise = True)
        MCMC_params = dict(
                state = previous_states[i],
                N_steps = int(5000),
                N_burn_in = int(0),
                thin = 10,
                logger = Eigenspectrum_IPR_all(bins = 10000, limit = 20),
                proposal = p_one_or_two,
                accept_function = perturbation_accept,
                warnings = True,
            raw_steps = True,
            )

        t0 = time()
        logs[i] = FK_mcmc(**MCMC_params, parameters = parameters)
        logs[i].time = time() - t0
        
        previous_states[i] = logs[i].last_state

        print(f'This N = {N} j ={i} took {time() - t0:.0f} seconds.')

        filepath = jobdir/f'{j}.npz'
        print(f'Saving in {filepath}')
        np.savez_compressed(filepath, 
        parameters = parameters, MCMC_params = MCMC_params, logs = logs, allow_pickle = True, Ns = Ns,
        )

    print(f'Overall: {time() - t1:.0f} seconds.\n\n')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# On round j = 0
# Starting N = 300
#
#             N = 300: 10% through after 0.00m             total = 500
#             c_accept = 25 c_reject = 475
#             q_accept = 2 q_reject = 23
#             prevented diagonalisation in 95.00% of cases
#             overall time = 0.2784230709075928
#             diagonalisation time = 0 54%
#             diagonalisation per step = 5.98ms
#             no-diagonalisation per step 0.26ms
#             unoptimised_time_per_step 6.23ms
#             optimised_time_per_step 0.56ms
#             computation reduced to 8.93%
#
#
#             N = 300: 20% through after 0.01m             total = 500
#             c_accept = 48 c_reject = 452
#             q_accept = 12 q_reject = 36
#             prevented diagonalisation in 90.40% of cases
#             overall time = 0.4445381164550781
#             diagonalisation time = 0 63%
#             diagonalisation per step = 5.82ms
#             no-diagonalisation per step 0.33ms
#             unoptimised_time_per_step 6.15ms
#             optimised_time_per_step 0.89ms
#             computation reduced to 14.45%
#
#
#             N = 300: 30% through after 0.02m             total = 500
#             c_accept = 53 c_reject = 447
#             q_accept = 18 q_reject = 35
#             prevented diagonalisation in 89.40% of cases
#             overall time = 0.459197998046875
#             diagonalisation time = 0 64%
#             diagonalisation per step = 5.59ms
#             no-diagonalisation per step 0.33ms
#             unoptimised_time_per_step 5.91ms
#             optimised_time_per_step 0.92ms
#             computation reduced to 15.53%
#
#
#             N = 300: 40% through after 0.03m             total = 500
#             c_accept = 53 c_reject = 447
#             q_accept = 22 q_reject = 31
#             prevented diagonalisation in 89.40% of cases
#             overall time = 0.4306068420410156
#             diagonalisation time = 0 69%
#             diagonalisation per step = 5.58ms
#             no-diagonalisation per step 0.27ms
#             unoptimised_time_per_step 5.85ms
#             optimised_time_per_step 0.86ms
#             computation reduced to 14.71%
#
#
#             N = 300: 50% through after 0.04m             total = 500
#             c_accept = 63 c_reject = 437
#             q_accept = 25 q_reject = 38
#             prevented diagonalisation in 87.40% of cases
#             overall time = 0.5380048751831055
#             diagonalisation time = 0 67%
#             diagonalisation per step = 5.69ms
#             no-diagonalisation per step 0.36ms
#             unoptimised_time_per_step 6.05ms
#             optimised_time_per_step 1.08ms
#             computation reduced to 17.79%
#
#
#             N = 300: 60% through after 0.04m             total = 500
#             c_accept = 52 c_reject = 448
#             q_accept = 23 q_reject = 29
#             prevented diagonalisation in 89.60% of cases
#             overall time = 0.48593783378601074
#             diagonalisation time = 0 65%
#             diagonalisation per step = 6.10ms
#             no-diagonalisation per step 0.34ms
#             unoptimised_time_per_step 6.44ms
#             optimised_time_per_step 0.97ms
#             computation reduced to 15.10%
#
#
#             N = 300: 70% through after 0.05m             total = 500
#             c_accept = 51 c_reject = 449
#             q_accept = 25 q_reject = 26
#             prevented diagonalisation in 89.80% of cases
#             overall time = 0.4491870403289795
#             diagonalisation time = 0 69%
#             diagonalisation per step = 6.04ms
#             no-diagonalisation per step 0.28ms
#             unoptimised_time_per_step 6.32ms
#             optimised_time_per_step 0.90ms
#             computation reduced to 14.22%
#
#
#             N = 300: 80% through after 0.06m             total = 500
#             c_accept = 52 c_reject = 448
#             q_accept = 24 q_reject = 28
#             prevented diagonalisation in 89.60% of cases
#             overall time = 0.5337960720062256
#             diagonalisation time = 0 63%
#             diagonalisation per step = 6.44ms
#             no-diagonalisation per step 0.40ms
#             unoptimised_time_per_step 6.83ms
#             optimised_time_per_step 1.07ms
#             computation reduced to 15.62%
#
#
#             N = 300: 90% through after 0.07m             total = 500
#             c_accept = 60 c_reject = 440
#             q_accept = 26 q_reject = 34
#             prevented diagonalisation in 88.00% of cases
#             overall time = 0.5340919494628906
#             diagonalisation time = 0 63%
#             diagonalisation per step = 5.65ms
#             no-diagonalisation per step 0.39ms
#             unoptimised_time_per_step 6.04ms
#             optimised_time_per_step 1.07ms
#             computation reduced to 17.69%
#
# Warning, p_acc = 0.0394, {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.6666666666666666, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# This N = 300 j =0 took 5 seconds.
# Saving in /Users/tom/HPC_data/local_run_data/benchmark_run/0.npz
# Overall: 5 seconds.
#
#
# On round j = 1
# Starting N = 300
#
#             N = 300: 10% through after 0.01m             total = 500
#             c_accept = 43 c_reject = 457
#             q_accept = 12 q_reject = 31
#             prevented diagonalisation in 91.40% of cases
#             overall time = 0.47295522689819336
#             diagonalisation time = 0 52%
#             diagonalisation per step = 5.68ms
#             no-diagonalisation per step 0.46ms
#             unoptimised_time_per_step 6.14ms
#             optimised_time_per_step 0.95ms
#             computation reduced to 15.41%
#
#
#             N = 300: 20% through after 0.02m             total = 500
#             c_accept = 69 c_reject = 431
#             q_accept = 30 q_reject = 39
#             prevented diagonalisation in 86.20% of cases
#             overall time = 0.6459462642669678
#             diagonalisation time = 0 61%
#             diagonalisation per step = 5.75ms
#             no-diagonalisation per step 0.50ms
#             unoptimised_time_per_step 6.25ms
#             optimised_time_per_step 1.29ms
#             computation reduced to 20.66%
#
#
#             N = 300: 30% through after 0.03m             total = 500
#             c_accept = 67 c_reject = 433
#             q_accept = 32 q_reject = 35
#             prevented diagonalisation in 86.60% of cases
#             overall time = 0.6182971000671387
#             diagonalisation time = 0 64%
#             diagonalisation per step = 5.87ms
#             no-diagonalisation per step 0.45ms
#             unoptimised_time_per_step 6.32ms
#             optimised_time_per_step 1.24ms
#             computation reduced to 19.56%
#
#
#             N = 300: 40% through after 0.04m             total = 500
#             c_accept = 81 c_reject = 419
#             q_accept = 35 q_reject = 46
#             prevented diagonalisation in 83.80% of cases
#             overall time = 0.705225944519043
#             diagonalisation time = 0 67%
#             diagonalisation per step = 5.81ms
#             no-diagonalisation per step 0.47ms
#             unoptimised_time_per_step 6.28ms
#             optimised_time_per_step 1.41ms
#             computation reduced to 22.45%
#
#
#             N = 300: 50% through after 0.05m             total = 500
#             c_accept = 62 c_reject = 438
#             q_accept = 26 q_reject = 36
#             prevented diagonalisation in 87.60% of cases
#             overall time = 0.5596568584442139
#             diagonalisation time = 0 63%
#             diagonalisation per step = 5.68ms
#             no-diagonalisation per step 0.42ms
#             unoptimised_time_per_step 6.09ms
#             optimised_time_per_step 1.12ms
#             computation reduced to 18.37%
#
#
#             N = 300: 60% through after 0.06m             total = 500
#             c_accept = 61 c_reject = 439
#             q_accept = 19 q_reject = 42
#             prevented diagonalisation in 87.80% of cases
#             overall time = 0.6067218780517578
#             diagonalisation time = 0 60%
#             diagonalisation per step = 6.00ms
#             no-diagonalisation per step 0.48ms
#             unoptimised_time_per_step 6.48ms
#             optimised_time_per_step 1.21ms
#             computation reduced to 18.73%
#
#
#             N = 300: 70% through after 0.07m             total = 500
#             c_accept = 58 c_reject = 442
#             q_accept = 20 q_reject = 38
#             prevented diagonalisation in 88.40% of cases
#             overall time = 0.55039381980896
#             diagonalisation time = 0 61%
#             diagonalisation per step = 5.79ms
#             no-diagonalisation per step 0.43ms
#             unoptimised_time_per_step 6.22ms
#             optimised_time_per_step 1.10ms
#             computation reduced to 17.70%
#
#
#             N = 300: 80% through after 0.08m             total = 500
#             c_accept = 60 c_reject = 440
#             q_accept = 16 q_reject = 44
#             prevented diagonalisation in 88.00% of cases
#             overall time = 0.5685040950775146
#             diagonalisation time = 0 63%
#             diagonalisation per step = 5.94ms
#             no-diagonalisation per step 0.42ms
#             unoptimised_time_per_step 6.37ms
#             optimised_time_per_step 1.14ms
#             computation reduced to 17.85%
#
#
#             N = 300: 90% through after 0.09m             total = 500
#             c_accept = 63 c_reject = 437
#             q_accept = 18 q_reject = 45
#             prevented diagonalisation in 87.40% of cases
#             overall time = 0.5926239490509033
#             diagonalisation time = 0 61%
#             diagonalisation per step = 5.74ms
#             no-diagonalisation per step 0.46ms
#             unoptimised_time_per_step 6.21ms
#             optimised_time_per_step 1.19ms
#             computation reduced to 19.10%
#
# Warning, p_acc = 0.0466, {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.6666666666666666, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# This N = 300 j =0 took 6 seconds.
# Saving in /Users/tom/HPC_data/local_run_data/benchmark_run/1.npz
# Overall: 11 seconds.
#
#
# On round j = 2
# Starting N = 300
#
#             N = 300: 10% through after 0.01m             total = 500
#             c_accept = 59 c_reject = 441
#             q_accept = 23 q_reject = 36
#             prevented diagonalisation in 88.20% of cases
#             overall time = 0.5302720069885254
#             diagonalisation time = 0 64%
#             diagonalisation per step = 5.73ms
#             no-diagonalisation per step 0.38ms
#             unoptimised_time_per_step 6.11ms
#             optimised_time_per_step 1.06ms
#             computation reduced to 17.35%
#
#
#             N = 300: 20% through after 0.02m             total = 500
#             c_accept = 40 c_reject = 460
#             q_accept = 16 q_reject = 24
#             prevented diagonalisation in 92.00% of cases
#             overall time = 0.4294719696044922
#             diagonalisation time = 0 57%
#             diagonalisation per step = 6.08ms
#             no-diagonalisation per step 0.37ms
#             unoptimised_time_per_step 6.46ms
#             optimised_time_per_step 0.86ms
#             computation reduced to 13.30%
#
#
#             N = 300: 30% through after 0.02m             total = 500
#             c_accept = 48 c_reject = 452
#             q_accept = 16 q_reject = 32
#             prevented diagonalisation in 90.40% of cases
#             overall time = 0.49379873275756836
#             diagonalisation time = 0 56%
#             diagonalisation per step = 5.77ms
#             no-diagonalisation per step 0.43ms
#             unoptimised_time_per_step 6.21ms
#             optimised_time_per_step 0.99ms
#             computation reduced to 15.91%
#
#
#             N = 300: 40% through after 0.03m             total = 500
#             c_accept = 57 c_reject = 443
#             q_accept = 24 q_reject = 33
#             prevented diagonalisation in 88.60% of cases
#             overall time = 0.5078330039978027
#             diagonalisation time = 0 66%
#             diagonalisation per step = 5.86ms
#             no-diagonalisation per step 0.35ms
#             unoptimised_time_per_step 6.21ms
#             optimised_time_per_step 1.02ms
#             computation reduced to 16.36%
#
#
#             N = 300: 50% through after 0.04m             total = 500
#             c_accept = 59 c_reject = 441
#             q_accept = 31 q_reject = 28
#             prevented diagonalisation in 88.20% of cases
#             overall time = 0.5090372562408447
#             diagonalisation time = 0 65%
#             diagonalisation per step = 5.62ms
#             no-diagonalisation per step 0.36ms
#             unoptimised_time_per_step 5.97ms
#             optimised_time_per_step 1.02ms
#             computation reduced to 17.05%
#
#
#             N = 300: 60% through after 0.05m             total = 500
#             c_accept = 64 c_reject = 436
#             q_accept = 23 q_reject = 41
#             prevented diagonalisation in 87.20% of cases
#             overall time = 0.6094579696655273
#             diagonalisation time = 0 60%
#             diagonalisation per step = 5.67ms
#             no-diagonalisation per step 0.49ms
#             unoptimised_time_per_step 6.16ms
#             optimised_time_per_step 1.22ms
#             computation reduced to 19.78%
#
#
#             N = 300: 70% through after 0.06m             total = 500
#             c_accept = 66 c_reject = 434
#             q_accept = 30 q_reject = 36
#             prevented diagonalisation in 86.80% of cases
#             overall time = 0.6378729343414307
#             diagonalisation time = 0 61%
#             diagonalisation per step = 5.91ms
#             no-diagonalisation per step 0.50ms
#             unoptimised_time_per_step 6.40ms
#             optimised_time_per_step 1.28ms
#             computation reduced to 19.92%
#
#
#             N = 300: 80% through after 0.07m             total = 500
#             c_accept = 51 c_reject = 449
#             q_accept = 21 q_reject = 30
#             prevented diagonalisation in 89.80% of cases
#             overall time = 0.4857490062713623
#             diagonalisation time = 0 59%
#             diagonalisation per step = 5.65ms
#             no-diagonalisation per step 0.39ms
#             unoptimised_time_per_step 6.05ms
#             optimised_time_per_step 0.97ms
#             computation reduced to 16.07%
#
#
#             N = 300: 90% through after 0.08m             total = 500
#             c_accept = 64 c_reject = 436
#             q_accept = 24 q_reject = 40
#             prevented diagonalisation in 87.20% of cases
#             overall time = 0.5648539066314697
#             diagonalisation time = 0 66%
#             diagonalisation per step = 5.80ms
#             no-diagonalisation per step 0.39ms
#             unoptimised_time_per_step 6.19ms
#             optimised_time_per_step 1.13ms
#             computation reduced to 18.26%
#
# Warning, p_acc = 0.0468, {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.6666666666666666, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# This N = 300 j =0 took 5 seconds.
# Saving in /Users/tom/HPC_data/local_run_data/benchmark_run/2.npz
# Overall: 16 seconds.
#
#
# On round j = 3
# Starting N = 300
#
#             N = 300: 10% through after 0.01m             total = 500
#             c_accept = 47 c_reject = 453
#             q_accept = 14 q_reject = 33
#             prevented diagonalisation in 90.60% of cases
#             overall time = 0.440885066986084
#             diagonalisation time = 0 61%
#             diagonalisation per step = 5.72ms
#             no-diagonalisation per step 0.34ms
#             unoptimised_time_per_step 6.06ms
#             optimised_time_per_step 0.88ms
#             computation reduced to 14.55%
#
#
#             N = 300: 20% through after 0.02m             total = 500
#             c_accept = 49 c_reject = 451
#             q_accept = 15 q_reject = 34
#             prevented diagonalisation in 90.20% of cases
#             overall time = 0.4884002208709717
#             diagonalisation time = 0 60%
#             diagonalisation per step = 5.97ms
#             no-diagonalisation per step 0.39ms
#             unoptimised_time_per_step 6.36ms
#             optimised_time_per_step 0.98ms
#             computation reduced to 15.36%
#
#
#             N = 300: 30% through after 0.02m             total = 500
#             c_accept = 49 c_reject = 451
#             q_accept = 11 q_reject = 38
#             prevented diagonalisation in 90.20% of cases
#             overall time = 0.4661378860473633
#             diagonalisation time = 0 62%
#             diagonalisation per step = 5.93ms
#             no-diagonalisation per step 0.35ms
#             unoptimised_time_per_step 6.28ms
#             optimised_time_per_step 0.93ms
#             computation reduced to 14.85%
#
#
#             N = 300: 40% through after 0.03m             total = 500
#             c_accept = 56 c_reject = 444
#             q_accept = 20 q_reject = 36
#             prevented diagonalisation in 88.80% of cases
#             overall time = 0.4955599308013916
#             diagonalisation time = 0 68%
#             diagonalisation per step = 6.01ms
#             no-diagonalisation per step 0.32ms
#             unoptimised_time_per_step 6.33ms
#             optimised_time_per_step 0.99ms
#             computation reduced to 15.67%
#
#
#             N = 300: 50% through after 0.04m             total = 500
#             c_accept = 68 c_reject = 432
#             q_accept = 22 q_reject = 46
#             prevented diagonalisation in 86.40% of cases
#             overall time = 0.7151682376861572
#             diagonalisation time = 0 57%
#             diagonalisation per step = 6.04ms
#             no-diagonalisation per step 0.61ms
#             unoptimised_time_per_step 6.65ms
#             optimised_time_per_step 1.43ms
#             computation reduced to 21.50%
#
#
#             N = 300: 60% through after 0.05m             total = 500
#             c_accept = 65 c_reject = 435
#             q_accept = 19 q_reject = 46
#             prevented diagonalisation in 87.00% of cases
#             overall time = 0.6137731075286865
#             diagonalisation time = 0 64%
#             diagonalisation per step = 6.01ms
#             no-diagonalisation per step 0.45ms
#             unoptimised_time_per_step 6.46ms
#             optimised_time_per_step 1.23ms
#             computation reduced to 19.00%
#
#
#             N = 300: 70% through after 0.07m             total = 500
#             c_accept = 71 c_reject = 429
#             q_accept = 25 q_reject = 46
#             prevented diagonalisation in 85.80% of cases
#             overall time = 0.6919937133789062
#             diagonalisation time = 0 65%
#             diagonalisation per step = 6.29ms
#             no-diagonalisation per step 0.49ms
#             unoptimised_time_per_step 6.78ms
#             optimised_time_per_step 1.38ms
#             computation reduced to 20.42%
#
#
#             N = 300: 80% through after 0.08m             total = 500
#             c_accept = 77 c_reject = 423
#             q_accept = 30 q_reject = 47
#             prevented diagonalisation in 84.60% of cases
#             overall time = 0.7291839122772217
#             diagonalisation time = 0 63%
#             diagonalisation per step = 6.00ms
#             no-diagonalisation per step 0.53ms
#             unoptimised_time_per_step 6.54ms
#             optimised_time_per_step 1.46ms
#             computation reduced to 22.31%
#
#
#             N = 300: 90% through after 0.09m             total = 500
#             c_accept = 62 c_reject = 438
#             q_accept = 29 q_reject = 33
#             prevented diagonalisation in 87.60% of cases
#             overall time = 0.5940470695495605
#             diagonalisation time = 0 63%
#             diagonalisation per step = 6.07ms
#             no-diagonalisation per step 0.44ms
#             unoptimised_time_per_step 6.50ms
#             optimised_time_per_step 1.19ms
#             computation reduced to 18.27%
#
# Warning, p_acc = 0.0418, {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.6666666666666666, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# This N = 300 j =0 took 6 seconds.
# Saving in /Users/tom/HPC_data/local_run_data/benchmark_run/3.npz
# Overall: 22 seconds.
#
#
# On round j = 4
# Starting N = 300
#
#             N = 300: 10% through after 0.01m             total = 500
#             c_accept = 58 c_reject = 442
#             q_accept = 18 q_reject = 40
#             prevented diagonalisation in 88.40% of cases
#             overall time = 0.5021350383758545
#             diagonalisation time = 0 66%
#             diagonalisation per step = 5.74ms
#             no-diagonalisation per step 0.34ms
#             unoptimised_time_per_step 6.08ms
#             optimised_time_per_step 1.00ms
#             computation reduced to 16.51%
#
#
#             N = 300: 20% through after 0.02m             total = 500
#             c_accept = 69 c_reject = 431
#             q_accept = 23 q_reject = 46
#             prevented diagonalisation in 86.20% of cases
#             overall time = 0.6334350109100342
#             diagonalisation time = 0 62%
#             diagonalisation per step = 5.72ms
#             no-diagonalisation per step 0.48ms
#             unoptimised_time_per_step 6.20ms
#             optimised_time_per_step 1.27ms
#             computation reduced to 20.43%
#
#
#             N = 300: 30% through after 0.03m             total = 500
#             c_accept = 60 c_reject = 440
#             q_accept = 23 q_reject = 37
#             prevented diagonalisation in 88.00% of cases
#             overall time = 0.5640819072723389
#             diagonalisation time = 0 62%
#             diagonalisation per step = 5.87ms
#             no-diagonalisation per step 0.42ms
#             unoptimised_time_per_step 6.29ms
#             optimised_time_per_step 1.13ms
#             computation reduced to 17.92%
#
#
#             N = 300: 40% through after 0.04m             total = 500
#             c_accept = 51 c_reject = 449
#             q_accept = 26 q_reject = 25
#             prevented diagonalisation in 89.80% of cases
#             overall time = 0.47416090965270996
#             diagonalisation time = 0 62%
#             diagonalisation per step = 5.74ms
#             no-diagonalisation per step 0.36ms
#             unoptimised_time_per_step 6.11ms
#             optimised_time_per_step 0.95ms
#             computation reduced to 15.53%
#
#
#             N = 300: 50% through after 0.05m             total = 500
#             c_accept = 75 c_reject = 425
#             q_accept = 23 q_reject = 52
#             prevented diagonalisation in 85.00% of cases
#             overall time = 0.6959407329559326
#             diagonalisation time = 0 64%
#             diagonalisation per step = 5.98ms
#             no-diagonalisation per step 0.50ms
#             unoptimised_time_per_step 6.47ms
#             optimised_time_per_step 1.39ms
#             computation reduced to 21.50%
#
#
#             N = 300: 60% through after 0.06m             total = 500
#             c_accept = 77 c_reject = 423
#             q_accept = 31 q_reject = 46
#             prevented diagonalisation in 84.60% of cases
#             overall time = 0.741462230682373
#             diagonalisation time = 0 64%
#             diagonalisation per step = 6.17ms
#             no-diagonalisation per step 0.53ms
#             unoptimised_time_per_step 6.71ms
#             optimised_time_per_step 1.48ms
#             computation reduced to 22.11%
#
#
#             N = 300: 70% through after 0.07m             total = 500
#             c_accept = 72 c_reject = 428
#             q_accept = 40 q_reject = 32
#             prevented diagonalisation in 85.60% of cases
#             overall time = 0.6272859573364258
#             diagonalisation time = 0 68%
#             diagonalisation per step = 5.96ms
#             no-diagonalisation per step 0.40ms
#             unoptimised_time_per_step 6.36ms
#             optimised_time_per_step 1.25ms
#             computation reduced to 19.73%
#
#
#             N = 300: 80% through after 0.08m             total = 500
#             c_accept = 81 c_reject = 419
#             q_accept = 31 q_reject = 50
#             prevented diagonalisation in 83.80% of cases
#             overall time = 0.7419817447662354
#             diagonalisation time = 0 66%
#             diagonalisation per step = 6.06ms
#             no-diagonalisation per step 0.50ms
#             unoptimised_time_per_step 6.56ms
#             optimised_time_per_step 1.48ms
#             computation reduced to 22.62%
#
#
#             N = 300: 90% through after 0.10m             total = 500
#             c_accept = 90 c_reject = 410
#             q_accept = 29 q_reject = 61
#             prevented diagonalisation in 82.00% of cases
#             overall time = 0.8056352138519287
#             diagonalisation time = 1 68%
#             diagonalisation per step = 6.12ms
#             no-diagonalisation per step 0.51ms
#             unoptimised_time_per_step 6.63ms
#             optimised_time_per_step 1.61ms
#             computation reduced to 24.32%
#
# Warning, p_acc = 0.0538, {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.6666666666666666, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# This N = 300 j =0 took 7 seconds.
# Saving in /Users/tom/HPC_data/local_run_data/benchmark_run/4.npz
# Overall: 29 seconds.
#
#
# On round j = 5
# Starting N = 300
#
#             N = 300: 10% through after 0.01m             total = 500
#             c_accept = 76 c_reject = 424
#             q_accept = 31 q_reject = 45
#             prevented diagonalisation in 84.80% of cases
#             overall time = 0.7221379280090332
#             diagonalisation time = 0 67%
#             diagonalisation per step = 6.33ms
#             no-diagonalisation per step 0.48ms
#             unoptimised_time_per_step 6.81ms
#             optimised_time_per_step 1.44ms
#             computation reduced to 21.20%
#
#
#             N = 300: 20% through after 0.03m             total = 500
#             c_accept = 90 c_reject = 410
#             q_accept = 39 q_reject = 51
#             prevented diagonalisation in 82.00% of cases
#             overall time = 0.8491017818450928
#             diagonalisation time = 1 67%
#             diagonalisation per step = 6.34ms
#             no-diagonalisation per step 0.56ms
#             unoptimised_time_per_step 6.89ms
#             optimised_time_per_step 1.70ms
#             computation reduced to 24.63%
#
#
#             N = 300: 30% through after 0.04m             total = 500
#             c_accept = 88 c_reject = 412
#             q_accept = 35 q_reject = 53
#             prevented diagonalisation in 82.40% of cases
#             overall time = 0.7861659526824951
#             diagonalisation time = 1 69%
#             diagonalisation per step = 6.20ms
#             no-diagonalisation per step 0.48ms
#             unoptimised_time_per_step 6.68ms
#             optimised_time_per_step 1.57ms
#             computation reduced to 23.54%
#
#
#             N = 300: 40% through after 0.05m             total = 500
#             c_accept = 79 c_reject = 421
#             q_accept = 27 q_reject = 52
#             prevented diagonalisation in 84.20% of cases
#             overall time = 0.778235912322998
#             diagonalisation time = 1 64%
#             diagonalisation per step = 6.34ms
#             no-diagonalisation per step 0.55ms
#             unoptimised_time_per_step 6.90ms
#             optimised_time_per_step 1.56ms
#             computation reduced to 22.57%
#
#
#             N = 300: 50% through after 0.07m             total = 500
#             c_accept = 86 c_reject = 414
#             q_accept = 24 q_reject = 62
#             prevented diagonalisation in 82.80% of cases
#             overall time = 0.7993588447570801
#             diagonalisation time = 1 64%
#             diagonalisation per step = 5.94ms
#             no-diagonalisation per step 0.58ms
#             unoptimised_time_per_step 6.52ms
#             optimised_time_per_step 1.60ms
#             computation reduced to 24.52%
#
#
#             N = 300: 60% through after 0.08m             total = 500
#             c_accept = 85 c_reject = 415
#             q_accept = 29 q_reject = 56
#             prevented diagonalisation in 83.00% of cases
#             overall time = 0.7706570625305176
#             diagonalisation time = 1 67%
#             diagonalisation per step = 6.08ms
#             no-diagonalisation per step 0.51ms
#             unoptimised_time_per_step 6.58ms
#             optimised_time_per_step 1.54ms
#             computation reduced to 23.41%
#
#
#             N = 300: 70% through after 0.09m             total = 500
#             c_accept = 84 c_reject = 416
#             q_accept = 27 q_reject = 57
#             prevented diagonalisation in 83.20% of cases
#             overall time = 0.8383207321166992
#             diagonalisation time = 1 65%
#             diagonalisation per step = 6.53ms
#             no-diagonalisation per step 0.58ms
#             unoptimised_time_per_step 7.11ms
#             optimised_time_per_step 1.68ms
#             computation reduced to 23.60%
#
#
#             N = 300: 80% through after 0.11m             total = 500
#             c_accept = 82 c_reject = 418
#             q_accept = 36 q_reject = 46
#             prevented diagonalisation in 83.60% of cases
#             overall time = 0.8200869560241699
#             diagonalisation time = 1 66%
#             diagonalisation per step = 6.57ms
#             no-diagonalisation per step 0.56ms
#             unoptimised_time_per_step 7.14ms
#             optimised_time_per_step 1.64ms
#             computation reduced to 22.98%
#
#
#             N = 300: 90% through after 0.12m             total = 500
#             c_accept = 99 c_reject = 401
#             q_accept = 47 q_reject = 52
#             prevented diagonalisation in 80.20% of cases
#             overall time = 0.8682200908660889
#             diagonalisation time = 1 72%
#             diagonalisation per step = 6.30ms
#             no-diagonalisation per step 0.49ms
#             unoptimised_time_per_step 6.79ms
#             optimised_time_per_step 1.74ms
#             computation reduced to 25.58%
#
# Warning, p_acc = 0.0682, {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.6666666666666666, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# This N = 300 j =0 took 8 seconds.
# Saving in /Users/tom/HPC_data/local_run_data/benchmark_run/5.npz
# Overall: 37 seconds.
#
#
# On round j = 6
# Starting N = 300
#
#             N = 300: 10% through after 0.02m             total = 500
#             c_accept = 109 c_reject = 391
#             q_accept = 41 q_reject = 68
#             prevented diagonalisation in 78.20% of cases
#             overall time = 1.0520219802856445
#             diagonalisation time = 1 69%
#             diagonalisation per step = 6.69ms
#             no-diagonalisation per step 0.65ms
#             unoptimised_time_per_step 7.33ms
#             optimised_time_per_step 2.10ms
#             computation reduced to 28.69%
#
#
#             N = 300: 20% through after 0.03m             total = 500
#             c_accept = 92 c_reject = 408
#             q_accept = 30 q_reject = 62
#             prevented diagonalisation in 81.60% of cases
#             overall time = 0.8892378807067871
#             diagonalisation time = 1 67%
#             diagonalisation per step = 6.50ms
#             no-diagonalisation per step 0.58ms
#             unoptimised_time_per_step 7.08ms
#             optimised_time_per_step 1.78ms
#             computation reduced to 25.12%
#
#
#             N = 300: 30% through after 0.05m             total = 500
#             c_accept = 89 c_reject = 411
#             q_accept = 35 q_reject = 54
#             prevented diagonalisation in 82.20% of cases
#             overall time = 0.7880380153656006
#             diagonalisation time = 1 70%
#             diagonalisation per step = 6.17ms
#             no-diagonalisation per step 0.48ms
#             unoptimised_time_per_step 6.64ms
#             optimised_time_per_step 1.58ms
#             computation reduced to 23.72%
#
#
#             N = 300: 40% through after 0.06m             total = 500
#             c_accept = 84 c_reject = 416
#             q_accept = 34 q_reject = 50
#             prevented diagonalisation in 83.20% of cases
#             overall time = 0.7981929779052734
#             diagonalisation time = 1 67%
#             diagonalisation per step = 6.36ms
#             no-diagonalisation per step 0.53ms
#             unoptimised_time_per_step 6.88ms
#             optimised_time_per_step 1.60ms
#             computation reduced to 23.19%
#
#
#             N = 300: 50% through after 0.07m             total = 500
#             c_accept = 76 c_reject = 424
#             q_accept = 30 q_reject = 46
#             prevented diagonalisation in 84.80% of cases
#             overall time = 0.761143684387207
#             diagonalisation time = 1 66%
#             diagonalisation per step = 6.61ms
#             no-diagonalisation per step 0.52ms
#             unoptimised_time_per_step 7.13ms
#             optimised_time_per_step 1.52ms
#             computation reduced to 21.35%
#
#
#             N = 300: 60% through after 0.08m             total = 500
#             c_accept = 61 c_reject = 439
#             q_accept = 24 q_reject = 37
#             prevented diagonalisation in 87.80% of cases
#             overall time = 0.62294602394104
#             diagonalisation time = 0 63%
#             diagonalisation per step = 6.40ms
#             no-diagonalisation per step 0.47ms
#             unoptimised_time_per_step 6.86ms
#             optimised_time_per_step 1.25ms
#             computation reduced to 18.15%
#
#
#             N = 300: 70% through after 0.09m             total = 500
#             c_accept = 59 c_reject = 441
#             q_accept = 27 q_reject = 32
#             prevented diagonalisation in 88.20% of cases
#             overall time = 0.5527248382568359
#             diagonalisation time = 0 67%
#             diagonalisation per step = 6.24ms
#             no-diagonalisation per step 0.37ms
#             unoptimised_time_per_step 6.61ms
#             optimised_time_per_step 1.11ms
#             computation reduced to 16.73%
#
#
#             N = 300: 80% through after 0.10m             total = 500
#             c_accept = 81 c_reject = 419
#             q_accept = 32 q_reject = 49
#             prevented diagonalisation in 83.80% of cases
#             overall time = 0.7822329998016357
#             diagonalisation time = 1 67%
#             diagonalisation per step = 6.48ms
#             no-diagonalisation per step 0.52ms
#             unoptimised_time_per_step 6.99ms
#             optimised_time_per_step 1.56ms
#             computation reduced to 22.37%
#
#
#             N = 300: 90% through after 0.11m             total = 500
#             c_accept = 54 c_reject = 446
#             q_accept = 22 q_reject = 32
#             prevented diagonalisation in 89.20% of cases
#             overall time = 0.5388989448547363
#             diagonalisation time = 0 65%
#             diagonalisation per step = 6.53ms
#             no-diagonalisation per step 0.37ms
#             unoptimised_time_per_step 6.90ms
#             optimised_time_per_step 1.08ms
#             computation reduced to 15.61%
#
# Warning, p_acc = 0.0596, {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.6666666666666666, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# This N = 300 j =0 took 7 seconds.
# Saving in /Users/tom/HPC_data/local_run_data/benchmark_run/6.npz
# Overall: 45 seconds.
#
#
# On round j = 7
# Starting N = 300
#
#             N = 300: 10% through after 0.01m             total = 500
#             c_accept = 51 c_reject = 449
#             q_accept = 16 q_reject = 35
#             prevented diagonalisation in 89.80% of cases
#             overall time = 0.5718960762023926
#             diagonalisation time = 0 57%
#             diagonalisation per step = 6.42ms
#             no-diagonalisation per step 0.49ms
#             unoptimised_time_per_step 6.91ms
#             optimised_time_per_step 1.14ms
#             computation reduced to 16.55%
#
#
#             N = 300: 20% through after 0.02m             total = 500
#             c_accept = 66 c_reject = 434
#             q_accept = 13 q_reject = 53
#             prevented diagonalisation in 86.80% of cases
#             overall time = 0.6551721096038818
#             diagonalisation time = 0 64%
#             diagonalisation per step = 6.36ms
#             no-diagonalisation per step 0.47ms
#             unoptimised_time_per_step 6.83ms
#             optimised_time_per_step 1.31ms
#             computation reduced to 19.18%
#
#
#             N = 300: 30% through after 0.03m             total = 500
#             c_accept = 67 c_reject = 433
#             q_accept = 18 q_reject = 49
#             prevented diagonalisation in 86.60% of cases
#             overall time = 0.6868109703063965
#             diagonalisation time = 0 59%
#             diagonalisation per step = 6.06ms
#             no-diagonalisation per step 0.56ms
#             unoptimised_time_per_step 6.62ms
#             optimised_time_per_step 1.37ms
#             computation reduced to 20.75%
#
#
#             N = 300: 40% through after 0.04m             total = 500
#             c_accept = 54 c_reject = 446
#             q_accept = 12 q_reject = 42
#             prevented diagonalisation in 89.20% of cases
#             overall time = 0.584993839263916
#             diagonalisation time = 0 58%
#             diagonalisation per step = 6.26ms
#             no-diagonalisation per step 0.49ms
#             unoptimised_time_per_step 6.75ms
#             optimised_time_per_step 1.17ms
#             computation reduced to 17.33%
#
#
#             N = 300: 50% through after 0.05m             total = 500
#             c_accept = 55 c_reject = 445
#             q_accept = 23 q_reject = 32
#             prevented diagonalisation in 89.00% of cases
#             overall time = 0.6020841598510742
#             diagonalisation time = 0 62%
#             diagonalisation per step = 6.78ms
#             no-diagonalisation per step 0.46ms
#             unoptimised_time_per_step 7.24ms
#             optimised_time_per_step 1.20ms
#             computation reduced to 16.63%
#
#
#             N = 300: 60% through after 0.06m             total = 500
#             c_accept = 57 c_reject = 443
#             q_accept = 17 q_reject = 40
#             prevented diagonalisation in 88.60% of cases
#             overall time = 0.5783941745758057
#             diagonalisation time = 0 60%
#             diagonalisation per step = 6.08ms
#             no-diagonalisation per step 0.46ms
#             unoptimised_time_per_step 6.55ms
#             optimised_time_per_step 1.16ms
#             computation reduced to 17.67%
#
#
#             N = 300: 70% through after 0.07m             total = 500
#             c_accept = 49 c_reject = 451
#             q_accept = 14 q_reject = 35
#             prevented diagonalisation in 90.20% of cases
#             overall time = 0.5351338386535645
#             diagonalisation time = 0 56%
#             diagonalisation per step = 6.08ms
#             no-diagonalisation per step 0.47ms
#             unoptimised_time_per_step 6.56ms
#             optimised_time_per_step 1.07ms
#             computation reduced to 16.32%
#
#
#             N = 300: 80% through after 0.08m             total = 500
#             c_accept = 57 c_reject = 443
#             q_accept = 19 q_reject = 38
#             prevented diagonalisation in 88.60% of cases
#             overall time = 0.5485107898712158
#             diagonalisation time = 0 62%
#             diagonalisation per step = 5.93ms
#             no-diagonalisation per step 0.42ms
#             unoptimised_time_per_step 6.35ms
#             optimised_time_per_step 1.10ms
#             computation reduced to 17.28%
#
#
#             N = 300: 90% through after 0.09m             total = 500
#             c_accept = 35 c_reject = 465
#             q_accept = 10 q_reject = 25
#             prevented diagonalisation in 93.00% of cases
#             overall time = 0.3855571746826172
#             diagonalisation time = 0 55%
#             diagonalisation per step = 6.05ms
#             no-diagonalisation per step 0.35ms
#             unoptimised_time_per_step 6.40ms
#             optimised_time_per_step 0.77ms
#             computation reduced to 12.05%
#
# Warning, p_acc = 0.0326, {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.6666666666666666, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# This N = 300 j =0 took 6 seconds.
# Saving in /Users/tom/HPC_data/local_run_data/benchmark_run/7.npz
# Overall: 50 seconds.
#
#
# On round j = 8
# Starting N = 300
#
#             N = 300: 10% through after 0.01m             total = 500
#             c_accept = 48 c_reject = 452
#             q_accept = 17 q_reject = 31
#             prevented diagonalisation in 90.40% of cases
#             overall time = 0.5303099155426025
#             diagonalisation time = 0 59%
#             diagonalisation per step = 6.55ms
#             no-diagonalisation per step 0.43ms
#             unoptimised_time_per_step 6.99ms
#             optimised_time_per_step 1.06ms
#             computation reduced to 15.18%
#
#
#             N = 300: 20% through after 0.02m             total = 500
#             c_accept = 68 c_reject = 432
#             q_accept = 24 q_reject = 44
#             prevented diagonalisation in 86.40% of cases
#             overall time = 0.7061688899993896
#             diagonalisation time = 0 61%
#             diagonalisation per step = 6.32ms
#             no-diagonalisation per step 0.55ms
#             unoptimised_time_per_step 6.87ms
#             optimised_time_per_step 1.41ms
#             computation reduced to 20.55%
#
#
#             N = 300: 30% through after 0.03m             total = 500
#             c_accept = 70 c_reject = 430
#             q_accept = 28 q_reject = 42
#             prevented diagonalisation in 86.00% of cases
#             overall time = 0.693713903427124
#             diagonalisation time = 0 64%
#             diagonalisation per step = 6.36ms
#             no-diagonalisation per step 0.50ms
#             unoptimised_time_per_step 6.86ms
#             optimised_time_per_step 1.39ms
#             computation reduced to 20.22%
#
#
#             N = 300: 40% through after 0.04m             total = 500
#             c_accept = 65 c_reject = 435
#             q_accept = 23 q_reject = 42
#             prevented diagonalisation in 87.00% of cases
#             overall time = 0.6779298782348633
#             diagonalisation time = 0 61%
#             diagonalisation per step = 6.32ms
#             no-diagonalisation per step 0.53ms
#             unoptimised_time_per_step 6.85ms
#             optimised_time_per_step 1.36ms
#             computation reduced to 19.79%
#
#
#             N = 300: 50% through after 0.06m             total = 500
#             c_accept = 76 c_reject = 424
#             q_accept = 25 q_reject = 51
#             prevented diagonalisation in 84.80% of cases
#             overall time = 0.711327075958252
#             diagonalisation time = 0 64%
#             diagonalisation per step = 6.02ms
#             no-diagonalisation per step 0.51ms
#             unoptimised_time_per_step 6.53ms
#             optimised_time_per_step 1.42ms
#             computation reduced to 21.80%
#
#
#             N = 300: 60% through after 0.07m             total = 500
#             c_accept = 94 c_reject = 406
#             q_accept = 29 q_reject = 65
#             prevented diagonalisation in 81.20% of cases
#             overall time = 0.9321401119232178
#             diagonalisation time = 1 66%
#             diagonalisation per step = 6.54ms
#             no-diagonalisation per step 0.63ms
#             unoptimised_time_per_step 7.17ms
#             optimised_time_per_step 1.86ms
#             computation reduced to 25.99%
#
#
#             N = 300: 70% through after 0.08m             total = 500
#             c_accept = 91 c_reject = 409
#             q_accept = 39 q_reject = 52
#             prevented diagonalisation in 81.80% of cases
#             overall time = 0.8232572078704834
#             diagonalisation time = 1 69%
#             diagonalisation per step = 6.25ms
#             no-diagonalisation per step 0.51ms
#             unoptimised_time_per_step 6.76ms
#             optimised_time_per_step 1.65ms
#             computation reduced to 24.35%
#
#
#             N = 300: 80% through after 0.10m             total = 500
#             c_accept = 70 c_reject = 430
#             q_accept = 28 q_reject = 42
#             prevented diagonalisation in 86.00% of cases
#             overall time = 0.7110292911529541
#             diagonalisation time = 0 63%
#             diagonalisation per step = 6.36ms
#             no-diagonalisation per step 0.53ms
#             unoptimised_time_per_step 6.89ms
#             optimised_time_per_step 1.42ms
#             computation reduced to 20.64%
#
#
#             N = 300: 90% through after 0.11m             total = 500
#             c_accept = 68 c_reject = 432
#             q_accept = 24 q_reject = 44
#             prevented diagonalisation in 86.40% of cases
#             overall time = 0.7320418357849121
#             diagonalisation time = 0 60%
#             diagonalisation per step = 6.47ms
#             no-diagonalisation per step 0.58ms
#             unoptimised_time_per_step 7.05ms
#             optimised_time_per_step 1.46ms
#             computation reduced to 20.76%
#
# Warning, p_acc = 0.0544, {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.6666666666666666, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# This N = 300 j =0 took 8 seconds.
# Saving in /Users/tom/HPC_data/local_run_data/benchmark_run/8.npz
# Overall: 58 seconds.
#
#
# On round j = 9
# Starting N = 300
#
#             N = 300: 10% through after 0.02m             total = 500
#             c_accept = 91 c_reject = 409
#             q_accept = 33 q_reject = 58
#             prevented diagonalisation in 81.80% of cases
#             overall time = 0.9058330059051514
#             diagonalisation time = 1 66%
#             diagonalisation per step = 6.54ms
#             no-diagonalisation per step 0.62ms
#             unoptimised_time_per_step 7.16ms
#             optimised_time_per_step 1.81ms
#             computation reduced to 25.30%
#
#
#             N = 300: 20% through after 0.03m             total = 500
#             c_accept = 85 c_reject = 415
#             q_accept = 36 q_reject = 49
#             prevented diagonalisation in 83.00% of cases
#             overall time = 0.8410172462463379
#             diagonalisation time = 1 65%
#             diagonalisation per step = 6.45ms
#             no-diagonalisation per step 0.59ms
#             unoptimised_time_per_step 7.03ms
#             optimised_time_per_step 1.68ms
#             computation reduced to 23.92%
#
#
#             N = 300: 30% through after 0.04m             total = 500
#             c_accept = 72 c_reject = 428
#             q_accept = 31 q_reject = 41
#             prevented diagonalisation in 85.60% of cases
#             overall time = 0.7173058986663818
#             diagonalisation time = 0 63%
#             diagonalisation per step = 6.26ms
#             no-diagonalisation per step 0.53ms
#             unoptimised_time_per_step 6.79ms
#             optimised_time_per_step 1.43ms
#             computation reduced to 21.12%
#
#
#             N = 300: 40% through after 0.05m             total = 500
#             c_accept = 71 c_reject = 429
#             q_accept = 24 q_reject = 47
#             prevented diagonalisation in 85.80% of cases
#             overall time = 0.7335150241851807
#             diagonalisation time = 0 63%
#             diagonalisation per step = 6.48ms
#             no-diagonalisation per step 0.55ms
#             unoptimised_time_per_step 7.03ms
#             optimised_time_per_step 1.47ms
#             computation reduced to 20.87%
#
#
#             N = 300: 50% through after 0.06m             total = 500
#             c_accept = 70 c_reject = 430
#             q_accept = 29 q_reject = 41
#             prevented diagonalisation in 86.00% of cases
#             overall time = 0.6776137351989746
#             diagonalisation time = 0 66%
#             diagonalisation per step = 6.38ms
#             no-diagonalisation per step 0.46ms
#             unoptimised_time_per_step 6.84ms
#             optimised_time_per_step 1.36ms
#             computation reduced to 19.81%
#
#
#             N = 300: 60% through after 0.08m             total = 500
#             c_accept = 106 c_reject = 394
#             q_accept = 47 q_reject = 59
#             prevented diagonalisation in 78.80% of cases
#             overall time = 1.0197510719299316
#             diagonalisation time = 1 70%
#             diagonalisation per step = 6.69ms
#             no-diagonalisation per step 0.62ms
#             unoptimised_time_per_step 7.31ms
#             optimised_time_per_step 2.04ms
#             computation reduced to 27.90%
#
#
#             N = 300: 70% through after 0.10m             total = 500
#             c_accept = 82 c_reject = 418
#             q_accept = 34 q_reject = 48
#             prevented diagonalisation in 83.60% of cases
#             overall time = 0.8185019493103027
#             diagonalisation time = 1 66%
#             diagonalisation per step = 6.60ms
#             no-diagonalisation per step 0.56ms
#             unoptimised_time_per_step 7.15ms
#             optimised_time_per_step 1.64ms
#             computation reduced to 22.89%
#
#
#             N = 300: 80% through after 0.11m             total = 500
#             c_accept = 108 c_reject = 392
#             q_accept = 34 q_reject = 74
#             prevented diagonalisation in 78.40% of cases
#             overall time = 1.0094962120056152
#             diagonalisation time = 1 69%
#             diagonalisation per step = 6.46ms
#             no-diagonalisation per step 0.62ms
#             unoptimised_time_per_step 7.08ms
#             optimised_time_per_step 2.02ms
#             computation reduced to 28.51%
#
#
#             N = 300: 90% through after 0.13m             total = 500
#             c_accept = 82 c_reject = 418
#             q_accept = 32 q_reject = 50
#             prevented diagonalisation in 83.60% of cases
#             overall time = 0.7940998077392578
#             diagonalisation time = 1 64%
#             diagonalisation per step = 6.24ms
#             no-diagonalisation per step 0.56ms
#             unoptimised_time_per_step 6.81ms
#             optimised_time_per_step 1.59ms
#             computation reduced to 23.33%
#
# Warning, p_acc = 0.0664, {'t': 1, 'alpha': 1.25, 'mu': 0, 'beta': 0.6666666666666666, 'J': 5, 'U': 5, 'normalise': True, 'J_matrix': 'suppressed for brevity'}
# This N = 300 j =0 took 8 seconds.
# Saving in /Users/tom/HPC_data/local_run_data/benchmark_run/9.npz
# Overall: 67 seconds.

# %% [markdown]
# T = 2.5 U = 5
#
# N = 300: 40% through after 0.17m             total = 500
# c_accept = 325 c_reject = 175
# q_accept = 181 q_reject = 144
# prevented diagonalisation in 35.00% of cases
# overall time = 2.5299150943756104
# diagonalisation time = 2 88%
# diagonalisation per step = 6.87ms
# no-diagonalisation per step 0.59ms
# unoptimised_time_per_step 7.47ms
# optimised_time_per_step 5.06ms
# computation reduced to 67.78%
#
# N = 50: 90% through after 0.03m             total = 500
# c_accept = 271 c_reject = 229
# q_accept = 159 q_reject = 112
# prevented diagonalisation in 45.80% of cases
# overall time = 0.17829084396362305
# diagonalisation time = 0 49%
# diagonalisation per step = 0.32ms
# no-diagonalisation per step 0.18ms
# unoptimised_time_per_step 0.50ms
# optimised_time_per_step 0.36ms
# computation reduced to 70.65%
#
# T = 1.5 U = 5
#
# N = 300: 90% through after 0.13m             total = 500
# c_accept = 82 c_reject = 418
# q_accept = 32 q_reject = 50
# prevented diagonalisation in 83.60% of cases
# overall time = 0.7940998077392578
# diagonalisation time = 1 64%
# diagonalisation per step = 6.24ms
# no-diagonalisation per step 0.56ms
# unoptimised_time_per_step 6.81ms
# optimised_time_per_step 1.59ms
# computation reduced to 23.33%
#
# N = 50: 90% through after 0.02m             total = 500
# c_accept = 111 c_reject = 389
# q_accept = 36 q_reject = 75
# prevented diagonalisation in 77.80% of cases
# overall time = 0.15433216094970703
# diagonalisation time = 0 31%
# diagonalisation per step = 0.43ms
# no-diagonalisation per step 0.21ms
# unoptimised_time_per_step 0.64ms
# optimised_time_per_step 0.31ms
# computation reduced to 47.96%
