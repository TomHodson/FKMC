# %%
'''
'''
from munch import Munch
import numpy as np

########## Hamiltonian parameters ###########################################################################
Ham_params = Munch(
    t = 1,
    alpha = 1.25,
    mu = 0,
    beta = 'varying',
    J = 5,
    U = 'varying',
    normalise = True #Whether the long range interaction should be normalised against the CDW or not.
)
print('Ham_params: ', ' '.join(f'{k}={v},' for k,v in Ham_params.items()))

########## Variable Hamiltonian parameters ###########################################################################
chain_exts = np.arange(0,5) #the number of times to extend the chain maximum is about 50 on CX1
N_steps = int(1e3) #the number of MCMC steps in each individual task
thin = 10
print(f'''
Tasks per chain: {chain_exts.size},
Each doing {N_steps} steps,
{chain_exts.size*N_steps} total chain length,
{chain_exts.size*N_steps // thin} samples,
''')

Rs = np.arange(10)
Us = np.array([2, 5])
Ts = np.array([1.5,2.5])
Ns = np.array([40,  60,  70,  80, 100, 120, 150, 180, 220, 270])

from FKMC.montecarlo import Eigenspectrum_IPR_all
def loggerfactory(): return Eigenspectrum_IPR_all(bins = 2000, limit = 5)

structure_names = ['Rs','Us','Ts',] #Ns and chain_exts is dealt with separately
structure_dimensions = [Rs,Us,Ts,]

########## Monte Carlo parameters ###########################################################################
from FKMC.montecarlo import p_multi_site_uniform_reflect, perturbation_accept

initial_states = Munch(
    CDW1 = lambda N: np.arange(N, dtype = np.float64) % 2,
    CDW2 = lambda N: (np.arange(N, dtype = np.float64)+1) % 2,
    zeros = lambda N: np.zeros(N, dtype = np.float64),
    ones = lambda N: np.ones(N, dtype = np.float64),
)

state_factory = initial_states.CDW1

MCMC_params = Munch(
        N_steps = N_steps,
        N_burn_in = N_steps,
        thin = thin,
        proposal = p_multi_site_uniform_reflect,
        accept_function = perturbation_accept,
        warnings = False,
        raw_steps = False,
    )
print('MCMC_params: ', ' '.join(f'{k}={v},' for k,v in MCMC_params.items()))

########## Batch Job Structure ###########################################################################
from itertools import product as cartesian_product

config_product = cartesian_product(*structure_dimensions)

#give information to the dispatch script
batch_params = Munch(
    total_jobs = np.prod([len(dim) for dim in structure_dimensions]),
    chain_exts = chain_exts,
    structure_names = structure_names, #names of each of the dimensions like ['Ts', 'Alphas']
    structure_dimensions = structure_dimensions, #the dimensions themselves like [np.linspace(0.1,5,100), np.linspace(0.1,2,100)]
    indices = (0, np.prod([len(dim) for dim in structure_dimensions])),
)
#bath_params_end_flag this is here to signal the end of the batch_params variable

########## Parameters particular to this job ################################################################

from itertools import product, islice
from pathlib import Path
import os
from time import time, sleep
import sys
import shutil
from FKMC.import_funcs import timefmt

print('Getting environment variables')
debug = (os.getenv('DEBUG', 'True') == 'True')
print(f'Debug = {debug}')
submit_dir = Path(os.getenv('SUBMIT_DIR', Path('~/HPC_data/test/').expanduser()))

job_id = int(os.getenv('JOB_ID', -1))
chain_id = int(os.getenv('CHAIN_ID', -1))
task_id = int(os.getenv('TASK_ID', 0))

print(f'job_id = {job_id}, chain_id = {chain_id}, task_id = {task_id}, submit_dir = {submit_dir}')

Is_todo = np.arange(len(Ns))
Ns_todo = Ns.copy()
logs = [None for _ in Ns]

filename = f'{task_id}_{chain_id}.npz'

if not debug and (submit_dir / 'data' / filename).exists():
    print(f'Job file {filename} already exists')
    print(f'Loading {filename} to retrieve the work')
    d = Munch(np.load(submit_dir / 'data' / filename, allow_pickle = True))
    logs = d['logs'][()]
    todo = (logs == None)
    Is_todo = Is_todo[todo]
    Ns_todo = Ns_todo[todo]
    print(f'Ns_todo = {Ns_todo}')
    


(R,U,T,), = list(islice(config_product, task_id, task_id + 1))
print(f'R (repeat) = {R}, U = {U}, T = {T}')
    
Ham_params.beta = 1 / T
Ham_params.U = U

########## Set up debugging and sleep ################################################################
original_MCMC_params = MCMC_params.copy()

raw_steps = False
if debug:
    MCMC_params.N_burn_in = 0
    MCMC_params.N_steps = 10
    MCMC_params.thin = 1
    #Ham_params.beta = 1 / 2.0 #choose the critical temp where the calculations take longest
    MCMC_params.raw_steps = True
    

##sleep if necessary
if not debug: 
    sleeptime = np.random.random() * (10)
    print(f'Waiting for {sleeptime:.0f} seconds to randomise the finish time')
    sleep(sleeptime)


########## Load the previous states ################################################################

#load in the last state from the previous run or use initial_states
if not debug and chain_id > 0:
    MCMC_params.N_burn_in = 0
    
    previous_filename = f'{task_id}_{chain_id-1}.npz'
    
    print(f'Loading {previous_filename} to retrieve the last state')
    d = Munch(np.load(submit_dir / 'data' / previous_filename, allow_pickle = True))
    previous_logs = d['logs'][()]
    if any(log == None for log in previous_logs):
        print("Previous job didn't finish, exiting")
        raise ValueError
        
    previous_states = {log.N_sites : log.last_state for log in previous_logs}
else:
    print('Generating initial state as this is the first run with these params')
    previous_states = {N : state_factory(N) for N in Ns_todo}

from FKMC.general import tridiagonal_diagonalisation_benchmark
benchmark_time = tridiagonal_diagonalisation_benchmark()
print(f"Diagonalisation benchmark: {benchmark_time:.2f} seconds")

########## The actual simulation code ################################################################
from FKMC.montecarlo import FK_mcmc

Ham_params.J_matrix = '...'
MCMC_params.state = '...'
t0 = time()

for i, N in zip(Is_todo, Ns_todo):
    MCMC_params.state = previous_states[N]
    MCMC_params.logger = loggerfactory()
    
    t0 = time()
    logs[i] = FK_mcmc(**MCMC_params, parameters = Ham_params)
    logs[i].time = time() - t0
    
    #restore these parameters for saving
    MCMC_params.N_burn_in = original_MCMC_params.N_burn_in
    
    np.savez_compressed(filename, 
        Ns = Ns, parameters = Ham_params, MCMC_params = MCMC_params, 
        structure_names = structure_names,
        structure_dimensions = structure_dimensions,        
        chain_id = chain_id,
        task_id = task_id,
        logs = logs, allow_pickle = True,
        desc = '',
        )
    
    shutil.copy(filename, submit_dir / 'data')

t = time() - t0
print(f'{t:.0f} seconds, final saving in {Path.cwd()} / {filename}')
print(f'Copying to {submit_dir}/data)')

print(f'''
Requested MCMC steps: {MCMC_params.N_steps}
Time: {timefmt(t)} 
Estimated task runtime for 1000 steps: {timefmt(t * 1000 / MCMC_params.N_steps)} 
''')
print('Done')
# Out:
# Ham_params:  t=1, alpha=1.25, mu=0, beta=varying, J=5, U=varying, normalise=True,
#
# Tasks per chain: 5,
# Each doing 1000 steps,
# 5000 total chain length,
# 500 samples,
#
# MCMC_params:  N_steps=1000, N_burn_in=1000, thin=10, proposal=<function p_multi_site_uniform_reflect at 0x2b97ab6f3f80>, accept_function=<function perturbation_accept at 0x2b97ab6fc560>, warnings=False, raw_steps=False,
# Getting environment variables
# Debug = True
# job_id = -1, chain_id = -1, task_id = 0, submit_dir = /rds/general/user/tch14/home/HPC_data/test
# R (repeat) = 0, U = 2, T = 1.5
# Generating initial state as this is the first run with these params
# Diagonalisation benchmark: 48.42 seconds
# N = 40: 0% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 40: 10% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 40: 20% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 40: 30% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 40: 40% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 40: 50% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 40: 60% through after 0.00m             acceptance rates: classical = 17% quantum = 1e+02% overall = 17%
# N = 40: 70% through after 0.00m             acceptance rates: classical = 14% quantum = 1e+02% overall = 14%
# N = 40: 80% through after 0.00m             acceptance rates: classical = 12% quantum = 1e+02% overall = 12%
# N = 40: 90% through after 0.00m             acceptance rates: classical = 11% quantum = 1e+02% overall = 11%
# N = 60: 0% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 60: 10% through after 0.01m             acceptance rates: classical = 0.99% quantum = 0% overall = 0%
# N = 60: 20% through after 0.01m             acceptance rates: classical = 2% quantum = 50% overall = 0.99%
# N = 60: 30% through after 0.02m             acceptance rates: classical = 2% quantum = 50% overall = 0.99%
# N = 60: 40% through after 0.02m             acceptance rates: classical = 1.7% quantum = 57% overall = 0.99%
# N = 60: 50% through after 0.03m             acceptance rates: classical = 1.6% quantum = 62% overall = 0.99%
# N = 60: 60% through after 0.03m             acceptance rates: classical = 1.5% quantum = 67% overall = 0.99%
# N = 60: 70% through after 0.03m             acceptance rates: classical = 1.8% quantum = 77% overall = 1.4%
# N = 60: 80% through after 0.03m             acceptance rates: classical = 1.7% quantum = 79% overall = 1.4%
# N = 60: 90% through after 0.03m             acceptance rates: classical = 1.8% quantum = 81% overall = 1.4%
# N = 70: 0% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 70: 10% through after 0.01m             acceptance rates: classical = 2% quantum = 1e+02% overall = 2%
# N = 70: 20% through after 0.01m             acceptance rates: classical = 0.99% quantum = 1e+02% overall = 0.99%
# N = 70: 30% through after 0.01m             acceptance rates: classical = 0.66% quantum = 1e+02% overall = 0.66%
# N = 70: 40% through after 0.01m             acceptance rates: classical = 0.74% quantum = 1e+02% overall = 0.74%
# N = 70: 50% through after 0.01m             acceptance rates: classical = 0.59% quantum = 1e+02% overall = 0.59%
# N = 70: 60% through after 0.01m             acceptance rates: classical = 0.83% quantum = 1e+02% overall = 0.83%
# N = 70: 70% through after 0.02m             acceptance rates: classical = 0.99% quantum = 1e+02% overall = 0.99%
# N = 70: 80% through after 0.02m             acceptance rates: classical = 0.87% quantum = 1e+02% overall = 0.87%
# N = 70: 90% through after 0.02m             acceptance rates: classical = 0.77% quantum = 1e+02% overall = 0.77%
# N = 80: 0% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 80: 10% through after 0.01m             acceptance rates: classical = 2% quantum = 1e+02% overall = 2%
# N = 80: 20% through after 0.01m             acceptance rates: classical = 0.99% quantum = 1e+02% overall = 0.99%
# N = 80: 30% through after 0.02m             acceptance rates: classical = 0.99% quantum = 1e+02% overall = 0.99%
# N = 80: 40% through after 0.02m             acceptance rates: classical = 1.7% quantum = 1e+02% overall = 1.7%
# N = 80: 50% through after 0.02m             acceptance rates: classical = 1.6% quantum = 1e+02% overall = 1.6%
# N = 80: 60% through after 0.02m             acceptance rates: classical = 2% quantum = 1e+02% overall = 2%
# N = 80: 70% through after 0.02m             acceptance rates: classical = 2.1% quantum = 1e+02% overall = 2.1%
# N = 80: 80% through after 0.02m             acceptance rates: classical = 2.2% quantum = 1e+02% overall = 2.2%
# N = 80: 90% through after 0.02m             acceptance rates: classical = 2% quantum = 1e+02% overall = 2%
# N = 100: 0% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 100: 10% through after 0.00m             acceptance rates: classical = 0.99% quantum = 1e+02% overall = 0.99%
# N = 100: 20% through after 0.01m             acceptance rates: classical = 0.5% quantum = 1e+02% overall = 0.5%
# N = 100: 30% through after 0.01m             acceptance rates: classical = 0.66% quantum = 1e+02% overall = 0.66%
# N = 100: 40% through after 0.01m             acceptance rates: classical = 0.5% quantum = 1e+02% overall = 0.5%
# N = 100: 50% through after 0.01m             acceptance rates: classical = 0.4% quantum = 1e+02% overall = 0.4%
# N = 100: 60% through after 0.02m             acceptance rates: classical = 0.5% quantum = 1e+02% overall = 0.5%
# N = 100: 70% through after 0.02m             acceptance rates: classical = 0.57% quantum = 1e+02% overall = 0.57%
# N = 100: 80% through after 0.02m             acceptance rates: classical = 0.5% quantum = 1e+02% overall = 0.5%
# N = 100: 90% through after 0.02m             acceptance rates: classical = 0.44% quantum = 1e+02% overall = 0.44%
# N = 120: 0% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 120: 10% through after 0.01m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 120: 20% through after 0.01m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 120: 30% through after 0.01m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 120: 40% through after 0.02m             acceptance rates: classical = 0.25% quantum = 1e+02% overall = 0.25%
# N = 120: 50% through after 0.02m             acceptance rates: classical = 0.2% quantum = 1e+02% overall = 0.2%
# N = 120: 60% through after 0.02m             acceptance rates: classical = 0.17% quantum = 1e+02% overall = 0.17%
# N = 120: 70% through after 0.03m             acceptance rates: classical = 0.57% quantum = 1e+02% overall = 0.57%
# N = 120: 80% through after 0.03m             acceptance rates: classical = 0.99% quantum = 1e+02% overall = 0.99%
# N = 120: 90% through after 0.03m             acceptance rates: classical = 1.1% quantum = 1e+02% overall = 1.1%
# N = 150: 0% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 150: 10% through after 0.01m             acceptance rates: classical = 0.99% quantum = 1e+02% overall = 0.99%
# N = 150: 20% through after 0.01m             acceptance rates: classical = 0.5% quantum = 1e+02% overall = 0.5%
# N = 150: 30% through after 0.01m             acceptance rates: classical = 0.99% quantum = 1e+02% overall = 0.99%
# N = 150: 40% through after 0.01m             acceptance rates: classical = 0.99% quantum = 1e+02% overall = 0.99%
# N = 150: 50% through after 0.02m             acceptance rates: classical = 0.99% quantum = 1e+02% overall = 0.99%
# N = 150: 60% through after 0.03m             acceptance rates: classical = 0.83% quantum = 1e+02% overall = 0.83%
# N = 150: 70% through after 0.03m             acceptance rates: classical = 0.99% quantum = 1e+02% overall = 0.99%
# N = 150: 80% through after 0.03m             acceptance rates: classical = 1.1% quantum = 1e+02% overall = 1.1%
# N = 150: 90% through after 0.03m             acceptance rates: classical = 0.99% quantum = 1e+02% overall = 0.99%
# N = 180: 0% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 180: 10% through after 0.01m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 180: 20% through after 0.01m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 180: 30% through after 0.01m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 180: 40% through after 0.01m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 180: 50% through after 0.02m             acceptance rates: classical = 0.59% quantum = 1e+02% overall = 0.59%
# N = 180: 60% through after 0.02m             acceptance rates: classical = 0.5% quantum = 1e+02% overall = 0.5%
# N = 180: 70% through after 0.03m             acceptance rates: classical = 0.57% quantum = 1e+02% overall = 0.57%
# N = 180: 80% through after 0.03m             acceptance rates: classical = 0.5% quantum = 1e+02% overall = 0.5%
# N = 180: 90% through after 0.03m             acceptance rates: classical = 0.44% quantum = 1e+02% overall = 0.44%
# N = 220: 0% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 220: 10% through after 0.03m             acceptance rates: classical = 0.99% quantum = 1e+02% overall = 0.99%
# N = 220: 20% through after 0.06m             acceptance rates: classical = 0.5% quantum = 1e+02% overall = 0.5%
# N = 220: 30% through after 0.09m             acceptance rates: classical = 0.99% quantum = 1e+02% overall = 0.99%
# N = 220: 40% through after 0.11m             acceptance rates: classical = 0.74% quantum = 1e+02% overall = 0.74%
# N = 220: 50% through after 0.14m             acceptance rates: classical = 0.59% quantum = 1e+02% overall = 0.59%
# N = 220: 60% through after 0.17m             acceptance rates: classical = 0.5% quantum = 1e+02% overall = 0.5%
# N = 220: 70% through after 0.19m             acceptance rates: classical = 0.42% quantum = 1e+02% overall = 0.42%
# N = 220: 80% through after 0.23m             acceptance rates: classical = 0.5% quantum = 1e+02% overall = 0.5%
# N = 220: 90% through after 0.26m             acceptance rates: classical = 0.77% quantum = 86% overall = 0.66%
# N = 270: 0% through after 0.01m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 270: 10% through after 0.04m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 270: 20% through after 0.08m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 270: 30% through after 0.11m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 270: 40% through after 0.14m             acceptance rates: classical = 0.25% quantum = 1e+02% overall = 0.25%
# N = 270: 50% through after 0.17m             acceptance rates: classical = 0.2% quantum = 1e+02% overall = 0.2%
# N = 270: 60% through after 0.19m             acceptance rates: classical = 0.17% quantum = 1e+02% overall = 0.17%
# N = 270: 70% through after 0.21m             acceptance rates: classical = 0.14% quantum = 1e+02% overall = 0.14%
# N = 270: 80% through after 0.26m             acceptance rates: classical = 0.25% quantum = 1e+02% overall = 0.25%
# N = 270: 90% through after 0.29m             acceptance rates: classical = 0.22% quantum = 1e+02% overall = 0.22%
# 20 seconds, final saving in /rds/general/user/tch14/home/FKMC/batchscripts / 0_-1.npz
# Copying to /rds/general/user/tch14/home/HPC_data/test/data)
#
# Requested MCMC steps: 10
# Time: 19 seconds
# Estimated task runtime for 1000 steps: 32.0 minutes
#
# Done
