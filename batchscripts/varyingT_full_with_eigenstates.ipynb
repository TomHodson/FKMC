# %%
'''
A script to do a sweep over temperature to make:
    - the binder cumulant plot
    - the IPR and DOS color plots showing the band opening
    
TODO:

a repeat of ## data/slurm_runs/103867 but with 1e5 steps and alpha = 3 to show short range behaviour
For the band opening plot for short ranged. It's a fixed J=5, U=1, alpha = 3, with T from 0.1 to 4 with 200 steps
very fine energy spacing: logger = Eigenspectrum_IPR_all(bins = 2000, limit = 5),
'''
from munch import Munch
import numpy as np

########## Hamiltonian parameters ###########################################################################
Ham_params = Munch(
    t = 1,
    alpha = 1.25,
    mu = 0,
    beta = 'varying',
    J = 5,
    U = 5,
    normalise = True #Whether the long range interaction should be normalised against the CDW or not.
)
print('Ham_params: ', ' '.join(f'{k}={v},' for k,v in Ham_params.items()))

########## Variable Hamiltonian parameters ###########################################################################
chain_exts = np.arange(0,10) #the number of times to extend the chain maximum is about 50 on CX1
N_steps = int(5e3) #the number of MCMC steps in each individual task
thin = 10
print(f'''
Tasks per chain: {chain_exts.size},
Each doing {N_steps} steps,
{chain_exts.size*N_steps} total chain length,
{chain_exts.size*N_steps // thin} samples,
''')

Rs = np.arange(10)
Ts = np.linspace(0.1, 4, 25)
Ns = np.logspace(np.log10(15), np.log10(251), 8, dtype = np.int) // 10 * 10

from FKMC.montecarlo import all_and_eigenvects
def loggerfactory(): return all_and_eigenvects()

structure_names = ['Rs','Ts',] #Ns and chain_exts is dealt with separately
structure_dimensions = [Rs,Ts,]

########## Monte Carlo parameters ###########################################################################
from FKMC.montecarlo import p_multi_site_uniform_reflect, perturbation_accept

initial_states = Munch(
    CDW1 = lambda N: np.arange(N, dtype = np.float64) % 2,
    CDW2 = lambda N: (np.arange(N, dtype = np.float64)+1) % 2,
    zeros = lambda N: np.zeros(N, dtype = np.float64),
    ones = lambda N: np.ones(N, dtype = np.float64),
)

state_factory = initial_states.CDW1

MCMC_params = Munch(
        N_steps = N_steps,
        N_burn_in = N_steps,
        thin = thin,
        proposal = p_multi_site_uniform_reflect,
        accept_function = perturbation_accept,
        warnings = False,
    )
print('MCMC_params: ', ' '.join(f'{k}={v},' for k,v in MCMC_params.items()))

########## Batch Job Structure ###########################################################################
from itertools import product as cartesian_product

config_product = cartesian_product(*structure_dimensions)

#give information to the dispatch script
batch_params = Munch(
    total_jobs = len(Ts) * len(Rs),
    chain_exts = chain_exts,
    structure_names = structure_names, #names of each of the dimensions like ['Ts', 'Alphas']
    structure_dimensions = structure_dimensions, #the dimensions themselves like [np.linspace(0.1,5,100), np.linspace(0.1,2,100)]
    indices = (0, len(Ts) * len(Rs)),
)
#bath_params_end_flag this is here to signal the end of the batch_params variable

########## Parameters particular to this job ################################################################

from itertools import product, islice
from pathlib import Path
import os
from time import time, sleep
import sys
import shutil
from FKMC.import_funcs import timefmt

print('Getting environment variables')
debug = (os.getenv('DEBUG', 'True') == 'True')
submit_dir = Path(os.getenv('SUBMIT_DIR', Path('~/HPC_data/test/').expanduser()))

job_id = int(os.getenv('JOB_ID', -1))
chain_id = int(os.getenv('CHAIN_ID', -1))
task_id = int(os.getenv('TASK_ID', 0))

print(f'job_id = {job_id}, chain_id = {chain_id}, task_id = {task_id}, submit_dir = {submit_dir}')

Is_todo = np.arange(len(Ns))
Ns_todo = Ns.copy()
logs = [None for _ in Ns]

filename = f'{task_id}_{chain_id}.npz'

if not debug and (submit_dir / 'data' / filename).exists():
    print(f'Job file {filename} already exists')
    print(f'Loading {filename} to retrieve the work')
    d = Munch(np.load(submit_dir / 'data' / filename, allow_pickle = True))
    logs = d['logs'][()]
    todo = (logs == None)
    Is_todo = Is_todo[todo]
    Ns_todo = Ns_todo[todo]
    print(f'Ns_todo = {Ns_todo}')
    


(R,T,), = list(islice(config_product, task_id, task_id + 1))
print(f'R (repeat) = {R}, T = {T}')
    

Ham_params.beta = 1 / T

########## Set up debugging and sleep ################################################################

if debug:
    MCMC_params.N_burn_in = 0
    MCMC_params.N_steps = 100
    MCMC_params.thin = 1
    Ham_params.beta = 1 / 2.0 #choose the critical temp where the calculations take longest
    
    

##sleep if necessary
if not debug: 
    sleeptime = np.random.random() * (10)
    print(f'Waiting for {sleeptime:.0f} seconds to randomise the finish time')
    sleep(sleeptime)


########## Load the previous states ################################################################

#load in the last state from the previous run or use initial_states
if not debug and chain_id > 0:
    MCMC_params.N_burn_in = 0
    
    previous_filename = f'{task_id}_{chain_id-1}.npz'
    
    print(f'Loading {previous_filename} to retrieve the last state')
    d = Munch(np.load(submit_dir / 'data' / previous_filename, allow_pickle = True))
    previous_logs = d['logs'][()]
    if any(log == None for log in previous_logs):
        print("Previous job didn't finish, exiting")
        raise ValueError
        
    previous_states = {log.N_sites : log.last_state for log in previous_logs}
else:
    print('Generating initial state as this is the first run with these params')
    previous_states = {N : state_factory(N) for N in Ns_todo}

from FKMC.general import tridiagonal_diagonalisation_benchmark
benchmark_time = tridiagonal_diagonalisation_benchmark()
print(f"Diagonalisation benchmark: {benchmark_time:.2f} seconds")

########## The actual simulation code ################################################################
from FKMC.montecarlo import FK_mcmc

Ham_params['J_matrix'] = '...'
MCMC_params['state'] = '...'
t0 = time()

for i, N in zip(Is_todo, Ns_todo):
    MCMC_params.state = previous_states[N]
    MCMC_params.logger = loggerfactory()
    
    t0 = time()
    logs[i] = FK_mcmc(**MCMC_params, parameters = Ham_params)
    logs[i].time = time() - t0
    
    np.savez_compressed(filename, 
        Ns = Ns, parameters = Ham_params, MCMC_params = MCMC_params, 
        structure_names = structure_names,
        structure_dimensions = structure_dimensions,        
        chain_id = chain_id,
        task_id = task_id,
        logs = logs, allow_pickle = True,
        desc = ''
        )
    
    shutil.copy(filename, submit_dir / 'data')

t = time() - t0
print(f'{t:.0f} seconds, final saving in {Path.cwd()} / {filename}')
print(f'Copying to {submit_dir}/data)')

print(f'''
Requested MCMC steps: {MCMC_params.N_steps}
Time: {timefmt(t)} 
Estimated task runtime for 1000 steps: {timefmt(t * 1000 / MCMC_params.N_steps)} 
''')
print('Done')
# Out:
# Ham_params:  t=1, alpha=1.25, mu=0, beta=varying, J=5, U=5, normalise=True,
#
# Tasks per chain: 10,
# Each doing 5000 steps,
# 50000 total chain length,
# 5000 samples,
#
# MCMC_params:  N_steps=5000, N_burn_in=5000, thin=10, proposal=<function p_multi_site_uniform_reflect at 0x7feaa1bbf3b0>, accept_function=<function perturbation_accept at 0x7feaa1bbf680>, warnings=False,
# Getting environment variables
# job_id = -1, chain_id = -1, task_id = 0, submit_dir = /Users/tom/HPC_data/test
# R (repeat) = 0, T = 0.1
# Generating initial state as this is the first run with these params
# Diagonalisation benchmark: 0.52 seconds
# N = 10: 0% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 10: 10% through after 0.00m             acceptance rates: classical = 10% quantum = 1e+02% overall = 10%
# N = 10: 20% through after 0.00m             acceptance rates: classical = 10% quantum = 1e+02% overall = 10%
# N = 10: 30% through after 0.00m             acceptance rates: classical = 17% quantum = 1e+02% overall = 17%
# N = 10: 40% through after 0.00m             acceptance rates: classical = 12% quantum = 1e+02% overall = 12%
# N = 10: 50% through after 0.00m             acceptance rates: classical = 10% quantum = 1e+02% overall = 10%
# N = 10: 60% through after 0.00m             acceptance rates: classical = 13% quantum = 88% overall = 12%
# N = 10: 70% through after 0.00m             acceptance rates: classical = 13% quantum = 89% overall = 11%
# N = 10: 80% through after 0.00m             acceptance rates: classical = 12% quantum = 90% overall = 11%
# N = 10: 90% through after 0.00m             acceptance rates: classical = 11% quantum = 90% overall = 10%
# N = 20: 0% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 20: 10% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 20: 20% through after 0.00m             acceptance rates: classical = 2.5% quantum = 1e+02% overall = 2.5%
# N = 20: 30% through after 0.00m             acceptance rates: classical = 6.7% quantum = 38% overall = 2.5%
# N = 20: 40% through after 0.00m             acceptance rates: classical = 6.9% quantum = 27% overall = 1.9%
# N = 20: 50% through after 0.00m             acceptance rates: classical = 6% quantum = 33% overall = 2%
# N = 20: 60% through after 0.00m             acceptance rates: classical = 6.2% quantum = 33% overall = 2.1%
# N = 20: 70% through after 0.00m             acceptance rates: classical = 6.8% quantum = 26% overall = 1.8%
# N = 20: 80% through after 0.00m             acceptance rates: classical = 7.2% quantum = 22% overall = 1.6%
# N = 20: 90% through after 0.00m             acceptance rates: classical = 7.5% quantum = 19% overall = 1.4%
# N = 30: 0% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 30: 10% through after 0.00m             acceptance rates: classical = 6.7% quantum = 1e+02% overall = 6.7%
# N = 30: 20% through after 0.00m             acceptance rates: classical = 6.1% quantum = 82% overall = 5%
# N = 30: 30% through after 0.00m             acceptance rates: classical = 5.2% quantum = 79% overall = 4.1%
# N = 30: 40% through after 0.00m             acceptance rates: classical = 5% quantum = 83% overall = 4.2%
# N = 30: 50% through after 0.00m             acceptance rates: classical = 5.1% quantum = 87% overall = 4.4%
# N = 30: 60% through after 0.00m             acceptance rates: classical = 4.6% quantum = 84% overall = 3.9%
# N = 30: 70% through after 0.00m             acceptance rates: classical = 4.1% quantum = 85% overall = 3.5%
# N = 30: 80% through after 0.00m             acceptance rates: classical = 3.6% quantum = 85% overall = 3.1%
# N = 30: 90% through after 0.00m             acceptance rates: classical = 3.5% quantum = 79% overall = 2.7%
# N = 50: 0% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# /Users/tom/miniconda3/envs/FKMC/lib/python3.7/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# N = 50: 10% through after 0.00m             acceptance rates: classical = 1.2% quantum = 67% overall = 0.8%
# N = 50: 20% through after 0.00m             acceptance rates: classical = 1.4% quantum = 43% overall = 0.6%
# N = 50: 30% through after 0.00m             acceptance rates: classical = 2.1% quantum = 31% overall = 0.67%
# N = 50: 40% through after 0.00m             acceptance rates: classical = 2.2% quantum = 50% overall = 1.1%
# N = 50: 50% through after 0.00m             acceptance rates: classical = 2.5% quantum = 65% overall = 1.6%
# N = 50: 60% through after 0.00m             acceptance rates: classical = 2.3% quantum = 68% overall = 1.5%
# N = 50: 70% through after 0.00m             acceptance rates: classical = 2.1% quantum = 70% overall = 1.5%
# N = 50: 80% through after 0.01m             acceptance rates: classical = 2.1% quantum = 74% overall = 1.6%
# N = 50: 90% through after 0.01m             acceptance rates: classical = 2.2% quantum = 64% overall = 1.4%
# N = 70: 0% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 70: 10% through after 0.00m             acceptance rates: classical = 2% quantum = 30% overall = 0.61%
# N = 70: 20% through after 0.00m             acceptance rates: classical = 1.4% quantum = 36% overall = 0.51%
# N = 70: 30% through after 0.00m             acceptance rates: classical = 1.9% quantum = 36% overall = 0.68%
# N = 70: 40% through after 0.01m             acceptance rates: classical = 1.9% quantum = 42% overall = 0.82%
# N = 70: 50% through after 0.01m             acceptance rates: classical = 2% quantum = 42% overall = 0.82%
# N = 70: 60% through after 0.01m             acceptance rates: classical = 1.9% quantum = 47% overall = 0.92%
# N = 70: 70% through after 0.01m             acceptance rates: classical = 2% quantum = 49% overall = 0.96%
# N = 70: 80% through after 0.01m             acceptance rates: classical = 2.2% quantum = 44% overall = 0.97%
# N = 70: 90% through after 0.01m             acceptance rates: classical = 2.3% quantum = 48% overall = 1.1%
# N = 110: 0% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 110: 10% through after 0.00m             acceptance rates: classical = 0.91% quantum = 73% overall = 0.66%
# N = 110: 20% through after 0.01m             acceptance rates: classical = 0.7% quantum = 82% overall = 0.58%
# N = 110: 30% through after 0.01m             acceptance rates: classical = 0.63% quantum = 74% overall = 0.47%
# N = 110: 40% through after 0.01m             acceptance rates: classical = 0.5% quantum = 75% overall = 0.37%
# N = 110: 50% through after 0.02m             acceptance rates: classical = 0.45% quantum = 70% overall = 0.31%
# N = 110: 60% through after 0.02m             acceptance rates: classical = 0.44% quantum = 72% overall = 0.32%
# N = 110: 70% through after 0.02m             acceptance rates: classical = 0.41% quantum = 71% overall = 0.3%
# N = 110: 80% through after 0.03m             acceptance rates: classical = 0.55% quantum = 49% overall = 0.27%
# N = 110: 90% through after 0.03m             acceptance rates: classical = 0.63% quantum = 41% overall = 0.26%
# N = 160: 0% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 160: 10% through after 0.01m             acceptance rates: classical = 0.47% quantum = 75% overall = 0.35%
# N = 160: 20% through after 0.01m             acceptance rates: classical = 0.64% quantum = 85% overall = 0.55%
# N = 160: 30% through after 0.02m             acceptance rates: classical = 0.56% quantum = 74% overall = 0.42%
# N = 160: 40% through after 0.03m             acceptance rates: classical = 0.42% quantum = 74% overall = 0.31%
# N = 160: 50% through after 0.03m             acceptance rates: classical = 0.35% quantum = 73% overall = 0.26%
# N = 160: 60% through after 0.04m             acceptance rates: classical = 0.3% quantum = 74% overall = 0.22%
# N = 160: 70% through after 0.05m             acceptance rates: classical = 0.28% quantum = 76% overall = 0.21%
# N = 160: 80% through after 0.05m             acceptance rates: classical = 0.29% quantum = 78% overall = 0.23%
# N = 160: 90% through after 0.06m             acceptance rates: classical = 0.34% quantum = 65% overall = 0.22%
# N = 250: 0% through after 0.00m             acceptance rates: classical = 0% quantum = 0% overall = 0%
# N = 250: 10% through after 0.02m             acceptance rates: classical = 0.5% quantum = 71% overall = 0.35%
# N = 250: 20% through after 0.04m             acceptance rates: classical = 0.42% quantum = 65% overall = 0.27%
# N = 250: 30% through after 0.06m             acceptance rates: classical = 0.31% quantum = 62% overall = 0.19%
# N = 250: 40% through after 0.08m             acceptance rates: classical = 0.29% quantum = 61% overall = 0.18%
# N = 250: 50% through after 0.10m             acceptance rates: classical = 0.3% quantum = 49% overall = 0.15%
# N = 250: 60% through after 0.11m             acceptance rates: classical = 0.27% quantum = 49% overall = 0.13%
# N = 250: 70% through after 0.13m             acceptance rates: classical = 0.26% quantum = 50% overall = 0.13%
# N = 250: 80% through after 0.15m             acceptance rates: classical = 0.25% quantum = 50% overall = 0.13%
# N = 250: 90% through after 0.17m             acceptance rates: classical = 0.25% quantum = 48% overall = 0.12%
# 16 seconds, final saving in /Users/tom/FKMC/batchscripts / 0_-1.npz
# Copying to /Users/tom/HPC_data/test/data)
#
# Requested MCMC steps: 100
# Time: 15 seconds
# Estimated task runtime for 1000 steps: 2.0 minutes
#
# Done
