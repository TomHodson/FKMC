# %%
'''
A script to do a sweep over temperature to make:
    - the binder cumulant plot
    - the IPR and DOS color plots showing the band opening
    
TODO:

a repeat of ## data/slurm_runs/103867 but with 1e5 steps and alpha = 3 to show short range behaviour
For the band opening plot for short ranged. It's a fixed J=5, U=1, alpha = 3, with T from 0.1 to 4 with 200 steps
very fine energy spacing: logger = Eigenspectrum_IPR_all(bins = 2000, limit = 5),
'''
from munch import Munch
import numpy as np

########## Hamiltonian parameters ###########################################################################
Ham_params = Munch(
    t = 1,
    alpha = 1.25,
    mu = 0,
    beta = 'varying',
    J = 5,
    U = 5,
    normalise = True #Whether the long range interaction should be normalised against the CDW or not.
)
print('Ham_params: ', ' '.join(f'{k}={v},' for k,v in Ham_params.items()))

########## Variable Hamiltonian parameters ###########################################################################
chain_exts = np.arange(0,2) #the number of times to extend the chain maximum is about 50 on CX1
N_steps = int(50) #the number of MCMC steps in each individual task
thin = 1
print(f'''
Tasks per chain: {chain_exts.size},
Each doing {N_steps} steps,
{chain_exts.size*N_steps} total chain length,
{chain_exts.size*N_steps // thin} samples,
''')

States = np.arange(4)
Rs = np.arange(5)
Ts = np.array([2,2.5])
Ns = np.logspace(np.log10(70), np.log10(1000), 10, dtype = np.int) // 10 * 10

from FKMC.montecarlo import Eigenspectrum_IPR_all
def loggerfactory(): return Eigenspectrum_IPR_all(bins = 2000, limit = 5)

structure_names = ['States','Rs','Ts',] #Ns and chain_exts is dealt with separately
structure_dimensions = [States,Rs,Ts,]

########## Monte Carlo parameters ###########################################################################
from FKMC.montecarlo import p_multi_site_uniform_reflect, perturbation_accept

initial_states = Munch(
    CDW1 = lambda N: np.arange(N, dtype = np.float64) % 2,
    CDW2 = lambda N: (np.arange(N, dtype = np.float64)+1) % 2,
    zeros = lambda N: np.zeros(N, dtype = np.float64),
    ones = lambda N: np.ones(N, dtype = np.float64),
)

MCMC_params = Munch(
        N_steps = N_steps,
        N_burn_in = N_steps,
        thin = thin,
        proposal = p_multi_site_uniform_reflect,
        accept_function = perturbation_accept,
        warnings = False,
    )
print('MCMC_params: ', ' '.join(f'{k}={v},' for k,v in MCMC_params.items()))

########## Batch Job Structure ###########################################################################
from itertools import product as cartesian_product

config_product = cartesian_product(*structure_dimensions)

#give information to the dispatch script
batch_params = Munch(
    total_jobs = len(States) * len(Ts) * len(Rs),
    chain_exts = chain_exts,
    structure_names = structure_names, #names of each of the dimensions like ['Ts', 'Alphas']
    structure_dimensions = structure_dimensions, #the dimensions themselves like [np.linspace(0.1,5,100), np.linspace(0.1,2,100)]
    indices = (0, len(States) * len(Ts) * len(Rs)),
)
#bath_params_end_flag this is here to signal the end of the batch_params variable

########## Parameters particular to this job ################################################################

from itertools import product, islice
from pathlib import Path
import os
from time import time, sleep
import sys
import shutil
from FKMC.import_funcs import timefmt

print('Getting environment variables')
debug = (os.getenv('DEBUG', 'True') == 'True')
submit_dir = Path(os.getenv('SUBMIT_DIR', Path('~/HPC_data/test/').expanduser()))

job_id = int(os.getenv('JOB_ID', -1))
chain_id = int(os.getenv('CHAIN_ID', -1))
task_id = int(os.getenv('TASK_ID', 0))

print(f'job_id = {job_id}, chain_id = {chain_id}, task_id = {task_id}, submit_dir = {submit_dir}')

Is_todo = np.arange(len(Ns))
Ns_todo = Ns.copy()
logs = [None for _ in Ns]

filename = f'{task_id}_{chain_id}.npz'

if not debug and (submit_dir / 'data' / filename).exists():
    print(f'Job file {filename} already exists')
    print(f'Loading {filename} to retrieve the work')
    d = Munch(np.load(submit_dir / 'data' / filename, allow_pickle = True))
    logs = d['logs'][()]
    todo = (logs == None)
    Is_todo = Is_todo[todo]
    Ns_todo = Ns_todo[todo]
    print(f'Ns_todo = {Ns_todo}')
    


(state,R,T,), = list(islice(config_product, task_id, task_id + 1))
print(f'state = {state}, R (repeat) = {R}, T = {T}')
state_factory = list(initial_states.values())[state]
    

Ham_params.beta = 1 / T

########## Set up debugging and sleep ################################################################
oldsteps = MCMC_params.N_steps
if debug:
    MCMC_params.N_steps = 10
    MCMC_params.N_burn_in = 0
    MCMC_params.N_steps = 10
    MCMC_params.thin = 1
    Ham_params.beta = 1 / 2.0 #choose the critical temp where the calculations take longest
    
    

##sleep if necessary
if not debug: 
    sleeptime = np.random.random() * (10)
    print(f'Waiting for {sleeptime:.0f} seconds to randomise the finish time')
    sleep(sleeptime)


########## Load the previous states ################################################################

#load in the last state from the previous run or use initial_states
if not debug and chain_id > 0:
    MCMC_params.N_burn_in = 0
    
    previous_filename = f'{task_id}_{chain_id-1}.npz'
    
    print(f'Loading {previous_filename} to retrieve the last state')
    d = Munch(np.load(submit_dir / 'data' / previous_filename, allow_pickle = True))
    previous_logs = d['logs'][()]
    if any(log == None for log in previous_logs):
        print("Previous job didn't finish, exiting")
        raise ValueError
        
    previous_states = {log.N_sites : log.last_state for log in previous_logs}
else:
    print('Generating initial state as this is the first run with these params')
    previous_states = {N : state_factory(N) for N in Ns_todo}

from FKMC.general import tridiagonal_diagonalisation_benchmark
benchmark_time = tridiagonal_diagonalisation_benchmark()
print(f"Diagonalisation benchmark: {benchmark_time:.2f} seconds")

########## The actual simulation code ################################################################
from FKMC.montecarlo import FK_mcmc

Ham_params['J_matrix'] = '...'
MCMC_params['state'] = '...'
t0 = time()

for i, N in zip(Is_todo, Ns_todo):
    MCMC_params.state = previous_states[N]
    MCMC_params.logger = loggerfactory()
    
    t1 = time()
    logs[i] = FK_mcmc(**MCMC_params, parameters = Ham_params)
    logs[i].time = time() - t1
    
    np.savez_compressed(filename, 
        Ns = Ns, parameters = Ham_params, MCMC_params = MCMC_params, 
        structure_names = structure_names,
        structure_dimensions = structure_dimensions,        
        chain_id = chain_id,
        task_id = task_id,
        logs = logs, allow_pickle = True,
        desc = ''
        )
    
    shutil.copy(filename, submit_dir / 'data')

t = time() - t0
print(f'{t:.0f} seconds, final saving in {Path.cwd()} / {filename}')
print(f'Copying to {submit_dir}/data)')

print(f'''
Requested MCMC steps: {MCMC_params.N_steps}
Time: {timefmt(t)} 
Estimated task runtime for {oldsteps} steps: {timefmt(t * oldsteps / MCMC_params.N_steps)} 
''')
print('Done')
# Out:
# Ham_params:  t=1, alpha=1.25, mu=0, beta=varying, J=5, U=5, normalise=True,
#
# Tasks per chain: 2,
# Each doing 50 steps,
# 100 total chain length,
# 100 samples,
#
# MCMC_params:  N_steps=50, N_burn_in=50, thin=1, proposal=<function p_multi_site_uniform_reflect at 0x2b7105b0f8c0>, accept_function=<function perturbation_accept at 0x2b7105b0fc20>, warnings=False,
# Getting environment variables
# job_id = -1, chain_id = -1, task_id = 0, submit_dir = /rds/general/user/tch14/home/HPC_data/test
# state = 0, R (repeat) = 0, T = 2.0
# Generating initial state as this is the first run with these params
# Diagonalisation benchmark: 1.56 seconds
# N = 70: 0% through after 0.00m             rejects: classical = nan% quantum = nan% overall = nan%
# N = 70: 10% through after 0.00m             rejects: classical = 100% quantum = nan% overall = 100%
# N = 70: 20% through after 0.00m             rejects: classical = 98% quantum = 0% overall = 98%
# N = 70: 30% through after 0.00m             rejects: classical = 99% quantum = 0% overall = 99%
# N = 70: 40% through after 0.00m             rejects: classical = 98% quantum = 0% overall = 98%
# N = 70: 50% through after 0.00m             rejects: classical = 98% quantum = 0% overall = 98%
# N = 70: 60% through after 0.00m             rejects: classical = 99% quantum = 0% overall = 99%
# N = 70: 70% through after 0.00m             rejects: classical = 98% quantum = 17% overall = 99%
# N = 70: 80% through after 0.00m             rejects: classical = 98% quantum = 14% overall = 98%
# N = 70: 90% through after 0.00m             rejects: classical = 98% quantum = 12% overall = 98%
# N = 90: 0% through after 0.00m             rejects: classical = nan% quantum = nan% overall = nan%
# /rdsgpfs/general/user/tch14/home/FKMC/FKMC/montecarlo.py:107: RuntimeWarning: invalid value encountered in double_scalars
#   c_r = 1 - (np.sum(logger.classical_accept_rates) / np.sum(logger.proposal_rates))
# /rdsgpfs/general/user/tch14/home/FKMC/FKMC/montecarlo.py:108: RuntimeWarning: invalid value encountered in double_scalars
#   q_r = 1 - np.sum(logger.accept_rates) / np.sum(logger.classical_accept_rates)
# /rdsgpfs/general/user/tch14/home/FKMC/FKMC/montecarlo.py:109: RuntimeWarning: invalid value encountered in double_scalars
#   o_r = 1 - np.sum(logger.accept_rates) / np.sum(logger.proposal_rates)
# N = 90: 10% through after 0.00m             rejects: classical = 100% quantum = nan% overall = 100%
# N = 90: 20% through after 0.00m             rejects: classical = 99% quantum = 100% overall = 100%
# N = 90: 30% through after 0.00m             rejects: classical = 100% quantum = 100% overall = 100%
# N = 90: 40% through after 0.00m             rejects: classical = 99% quantum = 50% overall = 100%
# N = 90: 50% through after 0.00m             rejects: classical = 99% quantum = 25% overall = 99%
# N = 90: 60% through after 0.00m             rejects: classical = 99% quantum = 20% overall = 99%
# N = 90: 70% through after 0.00m             rejects: classical = 99% quantum = 20% overall = 99%
# N = 90: 80% through after 0.00m             rejects: classical = 99% quantum = 12% overall = 99%
# N = 90: 90% through after 0.00m             rejects: classical = 99% quantum = 11% overall = 99%
# N = 120: 0% through after 0.00m             rejects: classical = nan% quantum = nan% overall = nan%
# N = 120: 10% through after 0.00m             rejects: classical = 97% quantum = 0% overall = 97%
# N = 120: 20% through after 0.00m             rejects: classical = 98% quantum = 0% overall = 98%
# N = 120: 30% through after 0.00m             rejects: classical = 98% quantum = 0% overall = 98%
# N = 120: 40% through after 0.00m             rejects: classical = 98% quantum = 0% overall = 98%
# N = 120: 50% through after 0.00m             rejects: classical = 98% quantum = 0% overall = 98%
# N = 120: 60% through after 0.00m             rejects: classical = 98% quantum = 7% overall = 98%
# N = 120: 70% through after 0.00m             rejects: classical = 98% quantum = 6% overall = 98%
# N = 120: 80% through after 0.00m             rejects: classical = 98% quantum = 10% overall = 98%
# N = 120: 90% through after 0.01m             rejects: classical = 98% quantum = 9% overall = 98%
# N = 160: 0% through after 0.00m             rejects: classical = nan% quantum = nan% overall = nan%
# N = 160: 10% through after 0.00m             rejects: classical = 98% quantum = 0% overall = 98%
# N = 160: 20% through after 0.00m             rejects: classical = 99% quantum = 0% overall = 99%
# N = 160: 30% through after 0.00m             rejects: classical = 99% quantum = 0% overall = 99%
# N = 160: 40% through after 0.00m             rejects: classical = 99% quantum = 0% overall = 99%
# N = 160: 50% through after 0.01m             rejects: classical = 99% quantum = 0% overall = 99%
# N = 160: 60% through after 0.01m             rejects: classical = 99% quantum = 0% overall = 99%
# N = 160: 70% through after 0.01m             rejects: classical = 99% quantum = 0% overall = 99%
# N = 160: 80% through after 0.01m             rejects: classical = 99% quantum = 0% overall = 99%
# N = 160: 90% through after 0.01m             rejects: classical = 99% quantum = 6% overall = 99%
# N = 220: 0% through after 0.00m             rejects: classical = nan% quantum = nan% overall = nan%
# N = 220: 10% through after 0.00m             rejects: classical = 99% quantum = 25% overall = 99%
# N = 220: 20% through after 0.00m             rejects: classical = 99% quantum = 17% overall = 99%
# N = 220: 30% through after 0.01m             rejects: classical = 99% quantum = 12% overall = 100%
# N = 220: 40% through after 0.01m             rejects: classical = 100% quantum = 22% overall = 100%
# N = 220: 50% through after 0.01m             rejects: classical = 100% quantum = 17% overall = 100%
# N = 220: 60% through after 0.01m             rejects: classical = 100% quantum = 17% overall = 100%
# N = 220: 70% through after 0.01m             rejects: classical = 100% quantum = 17% overall = 100%
# N = 220: 80% through after 0.02m             rejects: classical = 100% quantum = 17% overall = 100%
# N = 220: 90% through after 0.02m             rejects: classical = 100% quantum = 21% overall = 100%
# N = 300: 0% through after 0.00m             rejects: classical = nan% quantum = nan% overall = nan%
# N = 300: 10% through after 0.01m             rejects: classical = 99% quantum = 0% overall = 99%
# N = 300: 20% through after 0.01m             rejects: classical = 100% quantum = 14% overall = 100%
# N = 300: 30% through after 0.01m             rejects: classical = 100% quantum = 8% overall = 100%
# N = 300: 40% through after 0.02m             rejects: classical = 100% quantum = 13% overall = 100%
# N = 300: 50% through after 0.02m             rejects: classical = 100% quantum = 11% overall = 100%
# N = 300: 60% through after 0.03m             rejects: classical = 100% quantum = 17% overall = 100%
# N = 300: 70% through after 0.03m             rejects: classical = 100% quantum = 15% overall = 100%
# N = 300: 80% through after 0.04m             rejects: classical = 100% quantum = 18% overall = 100%
# N = 300: 90% through after 0.04m             rejects: classical = 100% quantum = 18% overall = 100%
# N = 410: 0% through after 0.00m             rejects: classical = nan% quantum = nan% overall = nan%
# N = 410: 10% through after 0.01m             rejects: classical = 100% quantum = 0% overall = 100%
# N = 410: 20% through after 0.02m             rejects: classical = 100% quantum = 0% overall = 100%
# N = 410: 30% through after 0.03m             rejects: classical = 100% quantum = 0% overall = 100%
# N = 410: 40% through after 0.04m             rejects: classical = 100% quantum = 0% overall = 100%
# N = 410: 50% through after 0.05m             rejects: classical = 100% quantum = 0% overall = 100%
# N = 410: 60% through after 0.06m             rejects: classical = 100% quantum = 4% overall = 100%
# N = 410: 70% through after 0.07m             rejects: classical = 100% quantum = 12% overall = 100%
# N = 410: 80% through after 0.08m             rejects: classical = 100% quantum = 11% overall = 100%
# N = 410: 90% through after 0.09m             rejects: classical = 100% quantum = 15% overall = 100%
# N = 550: 0% through after 0.00m             rejects: classical = nan% quantum = nan% overall = nan%
# N = 550: 10% through after 0.02m             rejects: classical = 100% quantum = 17% overall = 100%
# N = 550: 20% through after 0.04m             rejects: classical = 100% quantum = 8% overall = 100%
# N = 550: 30% through after 0.07m             rejects: classical = 100% quantum = 8% overall = 100%
# N = 550: 40% through after 0.09m             rejects: classical = 100% quantum = 11% overall = 100%
# N = 550: 50% through after 0.11m             rejects: classical = 100% quantum = 12% overall = 100%
# N = 550: 60% through after 0.13m             rejects: classical = 100% quantum = 22% overall = 100%
# N = 550: 70% through after 0.15m             rejects: classical = 100% quantum = 31% overall = 100%
# N = 550: 80% through after 0.17m             rejects: classical = 100% quantum = 39% overall = 100%
# N = 550: 90% through after 0.19m             rejects: classical = 100% quantum = 37% overall = 100%
# N = 740: 0% through after 0.00m             rejects: classical = nan% quantum = nan% overall = nan%
# N = 740: 10% through after 0.05m             rejects: classical = 100% quantum = 73% overall = 100%
# N = 740: 20% through after 0.09m             rejects: classical = 100% quantum = 44% overall = 100%
# N = 740: 30% through after 0.13m             rejects: classical = 100% quantum = 40% overall = 100%
# N = 740: 40% through after 0.18m             rejects: classical = 100% quantum = 57% overall = 100%
# N = 740: 50% through after 0.22m             rejects: classical = 100% quantum = 63% overall = 100%
# N = 740: 60% through after 0.26m             rejects: classical = 100% quantum = 62% overall = 100%
# N = 740: 70% through after 0.29m             rejects: classical = 100% quantum = 63% overall = 100%
# N = 740: 80% through after 0.32m             rejects: classical = 100% quantum = 61% overall = 100%
# N = 740: 90% through after 0.35m             rejects: classical = 100% quantum = 62% overall = 100%
# N = 1000: 0% through after 0.01m             rejects: classical = nan% quantum = nan% overall = nan%
# N = 1000: 10% through after 0.11m             rejects: classical = 100% quantum = 17% overall = 100%
# N = 1000: 20% through after 0.19m             rejects: classical = 100% quantum = 17% overall = 100%
# N = 1000: 30% through after 0.33m             rejects: classical = 100% quantum = 14% overall = 100%
# N = 1000: 40% through after 0.44m             rejects: classical = 100% quantum = 17% overall = 100%
# N = 1000: 50% through after 0.56m             rejects: classical = 100% quantum = 13% overall = 100%
# N = 1000: 60% through after 0.62m             rejects: classical = 100% quantum = 15% overall = 100%
# N = 1000: 70% through after 0.68m             rejects: classical = 100% quantum = 15% overall = 100%
# N = 1000: 80% through after 0.73m             rejects: classical = 100% quantum = 15% overall = 100%
# N = 1000: 90% through after 0.80m             rejects: classical = 100% quantum = 17% overall = 100%
# 98 seconds, final saving in /rdsgpfs/general/user/tch14/home/FKMC/batchscripts / 0_-1.npz
# Copying to /rds/general/user/tch14/home/HPC_data/test/data)
#
# Requested MCMC steps: 10
# Time: 1.0 minutes
# Estimated task runtime for 50 steps: 8.0 minutes
#
# Done
